# %%
import requests
import random
import pandas as pd
import os
from pathlib import Path
import win32com.client as win32
import win32com
import time
from datetime import datetime, timedelta
import pyotp
import pandas as pd
from SmartApi import SmartConnect
from logzero import logger
import requests

class BankNiftyDashboard:
    def __init__(self, api_key, username, pwd, token, file_path, offset_rows=0):
        self.api_key = api_key
        self.username = username
        self.pwd = pwd
        self.token = token
        self.file_path = file_path
        self.offset_rows = offset_rows

        self.symbol_token_map = {
            "HDFCBANK": "1333", "ICICIBANK": "4963", "AXISBANK": "5900", "KOTAKBANK": "1922",
            "SBIN": "3045", "INDUSINDBK": "5258", "BANDHANBNK": "2263", "PNB": "10666",
            "IDFCFIRSTB": "11184", "AUBANK": "21238", "FEDERALBNK": "1023", "BANKBARODA": "4668"
        }
        self.bank_nifty_stocks = list(self.symbol_token_map.keys())
        self.weight_map = {}
        self.last_weightage_fetch = None

        self.smartApi = SmartConnect(self.api_key)
        self.authenticate()
        self.wb, self.sheet = self.initialize_excel()

    def get_worksheet(self):
        import win32com.client
        excel = win32com.client.Dispatch("Excel.Application")
        excel.Visible = True
        if not os.path.exists(self.file_path):
            wb = excel.Workbooks.Add()
            ws = wb.Worksheets(1)
            wb.SaveAs(self.file_path)
        else:
            wb = excel.Workbooks.Open(self.file_path)
            ws = wb.Worksheets(1)
        return ws, wb

    def authenticate(self):
        try:
            totp = pyotp.TOTP(self.token).now()
        except Exception as e:
            logger.error("Invalid Token: The provided token is not valid.")
            raise e

        data = self.smartApi.generateSession(self.username, self.pwd, totp)
        if data['status'] == False:
            logger.error(data)
            raise Exception("Authentication failed")
        else:
            self.authToken = data['data']['jwtToken']
            self.refreshToken = data['data']['refreshToken']
            self.feedToken = self.smartApi.getfeedToken()
            self.profile = self.smartApi.getProfile(self.refreshToken)
            self.smartApi.generateToken(self.refreshToken)

    def get_banknifty_weightage(self):
        if self.last_weightage_fetch == datetime.now().date():
            return

        url = "https://www.smart-investing.in/indices-bse-nse.php?index=BANKNIFTY"
        try:
            tables = pd.read_html(url)
            for table in tables:
                cols = [col.lower() for col in table.columns.astype(str)]
                if "company" in cols and any("weight" in c for c in cols):
                    table.columns = [col.strip() for col in table.columns]
                    table = table.rename(columns={
                        table.columns[0]: "Bank Name",
                        table.columns[1]: "Weightage (%)"
                    })
                    table["Weightage (%)"] = table["Weightage (%)"].str.replace("%", "").astype(float)

                    alias_map = {
                        "HDFC BANK": "HDFCBANK",
                        "ICICI BANK": "ICICIBANK",
                        "AXIS BANK": "AXISBANK",
                        "KOTAK MAHINDRA BANK": "KOTAKBANK",
                        "STATE BANK OF INDIA": "SBIN",
                        "INDUSIND BANK": "INDUSINDBK",
                        "BANDHAN BANK": "BANDHANBNK",
                        "PUNJAB NATIONAL BANK": "PNB",
                        "IDFC FIRST BANK": "IDFCFIRSTB",
                        "AU SMALL FINANCE BANK": "AUBANK",
                        "THE FEDERAL BANK": "FEDERALBNK",
                        "BANK OF BARODA": "BANKBARODA"
                    }

                    self.weight_map.clear()
                    for _, row in table.iterrows():
                        full_name = row["Bank Name"].upper().replace(" LTD", "").strip()
                        symbol = alias_map.get(full_name, None)
                        if symbol:
                            self.weight_map[symbol] = row["Weightage (%)"]
                    self.last_weightage_fetch = datetime.now().date()
                    return
            print("Weightage table not found")
        except Exception as e:
            print("Error fetching weightage:", e)

    def initialize_excel(self):
        excel = win32com.client.gencache.EnsureDispatch("Excel.Application")
        excel.Visible = True

        if not os.path.exists(self.file_path):
            wb = excel.Workbooks.Add()
            sheet = wb.Worksheets(1)
            headers = ["Bank", "LTP", "Volume", "Change %", "Status", "Weightage"]
            for col, header in enumerate(headers, 1):
                sheet.Cells(1 + self.offset_rows, col).Value = header
            wb.SaveAs(self.file_path)
            return wb, sheet

        for wb in excel.Workbooks:
            if wb.FullName.lower() == self.file_path.lower():
                return wb, wb.Worksheets(1)
        try:
            wb = excel.Workbooks.Open(self.file_path)
            return wb, wb.Worksheets(1)
        except:
            wb = excel.Workbooks.Add()
            sheet = wb.Worksheets(1)
            headers = ["Bank", "LTP", "Volume", "Change %", "Status", "Weightage"]
            for col, header in enumerate(headers, 1):
                sheet.Cells(1 + self.offset_rows, col).Value = header
            wb.SaveAs(self.file_path)
            return wb, sheet

    def get_status(self, open, close):
        if (close > open):
            return "Bullish"
        elif (close < open):
            return "Bearish"
        return "Neutral"

    def update_excel(self):
        ws, wb = self.get_worksheet()

        def get_last_trading_day(current_date):
            last_trading_day = current_date - timedelta(days=1)
            if current_date.weekday() == 0:
                last_trading_day = current_date - timedelta(days=3)
            elif current_date.weekday() == 6:
                last_trading_day = current_date - timedelta(days=2)
            elif current_date.weekday() == 5:
                last_trading_day = current_date - timedelta(days=1)
            return last_trading_day

        now = datetime.now()
        today_open = now.replace(hour=9, minute=15, second=0, microsecond=0)
        market_close = now.replace(hour=15, minute=30, second=0, microsecond=0)

        if now.weekday() >= 5:
            print("⚠️ Market is closed on Saturday and Sunday.")
            last_trading_day = get_last_trading_day(now)
            from_date = last_trading_day.replace(hour=14, minute=30).strftime("%Y-%m-%d %H:%M")
            to_date = last_trading_day.replace(hour=15, minute=30).strftime("%Y-%m-%d %H:%M")
        else:
            if now < today_open:
                print("⚠️ Market has not opened yet. Try again after 9:15 AM.")
                last_trading_day = get_last_trading_day(now)
                from_date = last_trading_day.replace(hour=14, minute=30).strftime("%Y-%m-%d %H:%M")
                to_date = last_trading_day.replace(hour=15, minute=30).strftime("%Y-%m-%d %H:%M")
            elif now > market_close:
                print("⚠️ Market is closed for the day.")
                from_date = (market_close - timedelta(hours=1)).strftime("%Y-%m-%d %H:%M")
                to_date = market_close.strftime("%Y-%m-%d %H:%M")
            else:
                from_date = (now - timedelta(hours=1)).strftime("%Y-%m-%d %H:%M")
                to_date = now.strftime("%Y-%m-%d %H:%M")

        self.get_banknifty_weightage()
        # ws.UsedRange.Clear()
        headers = ["Bank", "LTP", "Volume", "Change %", "Status", "Weightage"]
        for col, header in enumerate(headers, 1):
            ws.Cells(1 + self.offset_rows, col).Value = header

        row_index = 2 + self.offset_rows
        for stock in self.bank_nifty_stocks:
            try:
                histParam = {
                    "exchange": "NSE",
                    "symboltoken": self.symbol_token_map[stock],
                    "interval": "ONE_MINUTE",
                    "fromdate": from_date,
                    "todate": to_date
                }
                response = self.smartApi.getCandleData(histParam)
                if response['status'] and response['data']:
                    candle = response['data'][-1]
                    ltp = candle[4]
                    volume = candle[5]
                    change_percent = ((candle[4] - candle[1]) / candle[1]) * 100
                    status = self.get_status(candle[1], candle[4]) 
                    weight = self.weight_map.get(stock.upper(), "")
                    ws.Cells(row_index, 1).Value = stock
                    ws.Cells(row_index, 2).Value = ltp
                    ws.Cells(row_index, 3).Value = volume
                    ws.Cells(row_index, 4).Value = round(change_percent, 2)
                    ws.Cells(row_index, 5).Value = status
                    ws.Cells(row_index, 6).Value = weight
                    row_index += 1
                else:
                    print(f"⚠️ Failed to get {stock} ONE_MINUTE data:", response)
            except Exception as e:
                print(f"❌ Error fetching {stock} data:", e)

        ws.Cells(row_index + 1, 1).Value = "Data Fetched At"
        ws.Cells(row_index + 1, 2).Value = to_date

        wb.Save()
        print(f"✅ Bank Nifty data updated in Excel at {datetime.now().strftime('%H:%M:%S')}")

    def run(self, interval_sec=60):
        try:
            while True:
                self.update_excel()
                time.sleep(interval_sec)
        except KeyboardInterrupt:
            print("Stopped by user.")
        except Exception as e:
            print("Unexpected error:", e)

class IndicesDashboard:
    def __init__(self, api_key, username, pwd, token, file_path):
        self.api_key = api_key
        self.username = username
        self.pwd = pwd
        self.token = token
        self.smartApi = SmartConnect(self.api_key)
        self.authenticate()
        self.file_path = file_path
        self.time_intervals = [
            "ONE_MINUTE", "THREE_MINUTE", "FIVE_MINUTE",
            "FIFTEEN_MINUTE", "THIRTY_MINUTE", "ONE_HOUR"
        ]
        latest_future = get_latest_banknifty_future()
        self.instruments = {
            "BANKNIFTY": {"token": "99926009", "exchange": "NSE"},
            "BANKNIFTY FUTURE": {"token": "56782", "exchange": "NFO"},
            "NIFTY": {"token": "99926000", "exchange": "NSE"},
            "INDIA VIX": {"token": "99926017", "exchange": "NSE"}
        }
        self.interval_mapping = {
            "ONE_MINUTE": "1min",
            "THREE_MINUTE": "3min",
            "FIVE_MINUTE": "5min",
            "FIFTEEN_MINUTE": "15min",
            "THIRTY_MINUTE": "30min",
            "ONE_HOUR": "1hr"
        }
        self.setup_excel_structure()

    def get_latest_banknifty_future(self):
        """
        Fetches the latest BANKNIFTY FUTURE token, symbol, expiry, and exchange segment.
        Returns a dict: {"token": ..., "symbol": ..., "expiry": ..., "exch_seg": ...}
        """
        import requests
        import pandas as pd

        url = 'https://margincalculator.angelone.in/OpenAPI_File/files/OpenAPIScripMaster.json'
        data = requests.get(url).json()
        df = pd.DataFrame(data)

        # Filter for BANKNIFTY futures (exclude options)
        banknifty_futures = df[df['symbol'].str.contains(r'^BANKNIFTY.*FUT', na=False)]
        # Get the latest expiry (sort by expiry descending)
        banknifty_futures = banknifty_futures.sort_values('expiry', ascending=False)
        if not banknifty_futures.empty:
            row = banknifty_futures.iloc[0]
            return {
                "token": str(row['token']),
                "symbol": row['symbol'],
                "expiry": row['expiry'],
                "exch_seg": row['exch_seg']
            }
        else:
            return None

    def clear_dashboard(self):
        ws, wb = self.get_worksheet()
        ws.UsedRange.Clear()
        wb.Save()
        print("Dashboard cleared.")

    def authenticate(self):
        try:
            totp = pyotp.TOTP(self.token).now()
        except Exception as e:
            logger.error("Invalid Token: The provided token is not valid.")
            raise e
        data = self.smartApi.generateSession(self.username, self.pwd, totp)
        if data['status'] == False:
            logger.error(data)
            raise Exception("Authentication failed")
        else:
            self.authToken = data['data']['jwtToken']
            self.refreshToken = data['data']['refreshToken']
            self.feedToken = self.smartApi.getfeedToken()
            self.profile = self.smartApi.getProfile(self.refreshToken)
            self.smartApi.generateToken(self.refreshToken)

    def get_worksheet(self):
        import win32com.client
        excel = win32com.client.gencache.EnsureDispatch("Excel.Application")
        excel.Visible = True
        if not os.path.exists(self.file_path):
            wb = excel.Workbooks.Add()
            ws = wb.Worksheets(1)
            wb.SaveAs(self.file_path)
        else:
            wb = excel.Workbooks.Open(self.file_path)
            ws = wb.Worksheets(1)
        return ws, wb
    
    def initialize_excel(self):
        excel = win32com.client.gencache.EnsureDispatch("Excel.Application")
        excel.Visible = True
        if os.path.exists(self.file_path):
            wb = excel.Workbooks.Open(self.file_path)
            print(f"Opened existing workbook: {self.file_path}")
        else:
            wb = excel.Workbooks.Add()
            wb.SaveAs(self.file_path)
            print(f"Created new workbook: {self.file_path}")
        ws = wb.Sheets(1)
        self.setup_excel_structure()
        return excel, wb, ws

    def setup_excel_structure(self):
        ws, wb = self.get_worksheet()
        ws.Name = "Indices Dashboard"
        ws.Range("A1").Value = f"Date: {datetime.now().strftime('%d-%m-%Y')}"
        ws.Range("A2").Value = f"Time: {datetime.now().strftime('%H:%M')}"
        headers = ["", "", "1min", "3min", "5min", "15min", "30min", "1hrs"]
        for col_idx, header in enumerate(headers, 1):
            ws.Cells(4, col_idx).Value = header
        row_labels = {6: "A", 8: "B", 10: "C", 12: "D", 14: "F"}
        indice_names = {6: "BANKNIFTY", 8: "BANKNIFTY FUTURE", 10: "NIFTY", 12: "GIFT NIFTY", 14: "VIX"}
        for col in range(2, 9):
            ws.Columns(col).ColumnWidth = 20
            ws.Columns(col).WrapText = True
        for row, label in row_labels.items():
            ws.Cells(row, 1).Value = label
        for row, label in indice_names.items():
            ws.Cells(row, 2).Value = label
        gradient_pairs = [6, 8, 10, 12, 14]
        base_color = 0xD3D3D3
        def darken_color(hex_color, step):
            r = (hex_color & 0xFF0000) >> 16
            g = (hex_color & 0x00FF00) >> 8
            b = (hex_color & 0x0000FF)
            r = max(0, r - step)
            g = max(0, g - step)
            b = max(0, b - step)
            return (r << 16) + (g << 8) + b
        current_color = base_color
        for top_row in gradient_pairs:
            for col in range(1, 11):
                ws.Cells(top_row, col).Interior.Color = current_color
                ws.Cells(top_row + 1, col).Interior.Color = current_color
            current_color = darken_color(current_color, 15)
        wb.Save()

    def fetch_candle_data(self, symbol, token, exchange, interval):
        now = datetime.now()
        market_open = now.replace(hour=9, minute=15, second=0, microsecond=0)
        market_close = now.replace(hour=15, minute=30, second=0, microsecond=0)
        def get_last_trading_day(current_date):
            last_trading_day = current_date - timedelta(days=1)
            if current_date.weekday() == 0:
                last_trading_day = current_date - timedelta(days=3)
            elif current_date.weekday() == 6:
                last_trading_day = current_date - timedelta(days=2)
            elif current_date.weekday() == 5:
                last_trading_day = current_date - timedelta(days=1)
            return last_trading_day
        if now.weekday() >= 5:
            last_trading_day = get_last_trading_day(now)
            from_date = last_trading_day.replace(hour=14, minute=30).strftime("%Y-%m-%d %H:%M")
            to_date = last_trading_day.replace(hour=15, minute=30).strftime("%Y-%m-%d %H:%M")
        else:
            if now < market_open:
                last_trading_day = get_last_trading_day(now)
                from_date = last_trading_day.replace(hour=14, minute=30).strftime("%Y-%m-%d %H:%M")
                to_date = last_trading_day.replace(hour=15, minute=30).strftime("%Y-%m-%d %H:%M")
            elif now > market_close:
                from_date = (market_close - timedelta(hours=1)).strftime("%Y-%m-%d %H:%M")
                to_date = market_close.strftime("%Y-%m-%d %H:%M")
            else:
                from_date = (now - timedelta(hours=1)).strftime("%Y-%m-%d %H:%M")
                to_date = now.strftime("%Y-%m-%d %H:%M")
        params = {
            "exchange": exchange,
            "symboltoken": token,
            "interval": interval,
            "fromdate": from_date,
            "todate": to_date
        }
        try:
            response = self.smartApi.getCandleData(params)
            if response['status'] and response['data']:
                data = response['data']
                latest = data[-1:]
                df = pd.DataFrame(latest, columns=["Datetime", "Open", "High", "Low", "Close", "Volume"])
                df["Symbol"] = symbol
                df["Interval"] = interval
                return df
            else:
                print(f"⚠️ No candle data for {symbol} ({interval})")
                return pd.DataFrame()
        except Exception as e:
            print(f"❌ Error fetching {symbol} [{interval}]: {e}")
            return pd.DataFrame()

    def fetch_and_process_data(self):
        final_df = pd.DataFrame()
        for symbol, info in self.instruments.items():
            for interval in self.time_intervals:
                df = self.fetch_candle_data(symbol, info["token"], info["exchange"], interval)
                final_df = pd.concat([final_df, df], ignore_index=True)
        final_df = final_df[["Symbol", "Interval", "Datetime", "Open", "High", "Low", "Close", "Volume"]]
        final_df.sort_values(by=["Symbol", "Interval", "Datetime"], inplace=True)
        return final_df

    def calculate_sentiment(self, df):
        
        def sentiment_logic(row):
            symbol = row["Symbol"]
            close_price = row["Close"]
            open_price = row["Open"]

            if (open_price < close_price):
                sentiment = f"Bullish"
            elif (open_price > close_price):
                sentiment = f"Bearish"
            else:
                sentiment = f"Neutral"

            return sentiment

        df["Sentiment"] = df.apply(sentiment_logic, axis=1)
        df["Interval"] = df["Interval"].map(self.interval_mapping)
        return df

    def update_excel(self, df):
        ws, wb = self.get_worksheet()
        cell_mapping = {
            "BANKNIFTY": {"1min": "C6", "3min": "D6", "5min": "E6", "15min": "F6", "30min": "G6", "1hr": "H6"},
            "BANKNIFTY FUTURE": {"1min": "C8", "3min": "D8", "5min": "E8", "15min": "F8", "30min": "G8", "1hr": "H8"},
            "NIFTY": {"1min": "C10", "3min": "D10", "5min": "E10", "15min": "F10", "30min": "G10", "1hr": "H10"},
            "INDIA VIX": {"1min": "C14", "3min": "D14", "5min": "E14", "15min": "F14", "30min": "G14", "1hr": "H14"}
        }
        ws.Range("A1").Value = f"Date: {datetime.now().strftime('%d-%m-%Y')}"
        ws.Range("A2").Value = f"Time: {datetime.now().strftime('%H:%M')}"
        for symbol in cell_mapping.keys():
            for interval, cell in cell_mapping[symbol].items():
                try:
                    sentiment = df[(df["Symbol"] == symbol) & (df["Interval"] == interval)]["Sentiment"].iloc[0]
                except IndexError:
                    print(f"Warning: No sentiment data for {symbol} ({interval})")
                    continue
                ws.Range(cell).Value = sentiment
                if "bullish" in sentiment.lower():
                    ws.Range(cell).Font.Color = 0x008000  # Green
                elif "bearish" in sentiment.lower():
                    ws.Range(cell).Font.Color = 0x0000FF  # Blue
                else:
                    ws.Range(cell).Font.Color = 0x000000  # Black
        wb = ws.Parent
        wb.Save()
        print("Excel file updated successfully.")

    def run(self):
        try:
            while True:
                try:
                    df = self.fetch_and_process_data()
                    df = self.calculate_sentiment(df)
                    self.update_excel(self.ws, df)
                    print(f"Data updated at {datetime.now().strftime('%H:%M:%S')}")
                except Exception as e:
                    print(f"Error during data update: {str(e)}")
                    if isinstance(e, requests.exceptions.ConnectionError):
                        print("Connection error detected. Retrying in 60 seconds...")
                time.sleep(60)
        except KeyboardInterrupt:
            print("Script interrupted by user.")
            try:
                self.wb.Save()
                self.wb.Close()
                self.excel.Quit()
                print("Excel application closed successfully.")
            except Exception as e:
                print(f"Error closing Excel: {str(e)}")
        except Exception as e:
            print(f"Fatal error: {str(e)}")
            try:
                self.wb.Close()
                self.excel.Quit()
            except:
                pass

# %%
file_path = r"C:\Users\jaiad\Pro T\Final_draft1\banknifty_dashboard.xlsx"

banknifty_args = {
    "api_key": '3tA3noq3',
    "username": 'AAAF620196',
    "pwd": '0054',
    "token": 'YS4MOR7OUZEHGNV3VFOQ5TVMRE',
    "file_path": file_path,
    "offset_rows": 15
}
indices_args = {
    "api_key": '3tA3noq3',
    "username": 'AAAF620196',
    "pwd": '0054',
    "token": 'YS4MOR7OUZEHGNV3VFOQ5TVMRE',
    "file_path": file_path
}


class DashboardIntegrator:
    def __init__(
        self,
        banknifty_args,
        indices_args,
        banknifty_interval=30
    ):
        self.banknifty_dashboard = BankNiftyDashboard(**banknifty_args)
        self.indices_dashboard = IndicesDashboard(**indices_args)
        self.indices_dashboard.clear_dashboard()
        self.indices_dashboard.setup_excel_structure()
        self.banknifty_interval = banknifty_interval
        #self.niftyupdater = OptionChainUpdaterCOM(file_path=file_path)
        #self.bankniftyupdater = BankOptionChainUpdaterCOM(file_path=file_path)

    def run(self):

        try:
            while True:
                try:
                    print("Updating Indices Dashboard...")
                    df = self.indices_dashboard.fetch_and_process_data()
                    df = self.indices_dashboard.calculate_sentiment(df)
                    self.indices_dashboard.update_excel(df)
                    print("Updating BankNifty Dashboard...")
                    self.banknifty_dashboard.update_excel()
                    print(f"Both dashboards updated at {datetime.now().strftime('%H:%M:%S')}")
                    # self.bankniftyupdater.run()
                    # self.niftyupdater.run()
                except Exception as e:
                    print(f"Error during update: {str(e)}")
                time.sleep(self.banknifty_interval)
        except KeyboardInterrupt:
            print("Stopped by user.")
        except Exception as e:
            print("Unexpected error:", e)

integrator = DashboardIntegrator(banknifty_args, indices_args, banknifty_interval=30)
integrator.run()
# Out:
# [I 250802 18:50:58 smartConnect:124] in pool
# [I 250802 18:51:01 smartConnect:124] in pool

# %% [markdown]
# # Trying to get the bank nifty futures and option token (changes every month)

# %%
import requests
import random
import pandas as pd
import os
from pathlib import Path
import win32com.client as win32
import win32com
import time
from datetime import datetime, timedelta
import pyotp
import pandas as pd
from SmartApi import SmartConnect
from logzero import logger
import requests

class BankNiftyDashboard:
    def __init__(self, api_key, username, pwd, token, file_path, offset_rows=0):
        self.api_key = api_key
        self.username = username
        self.pwd = pwd
        self.token = token
        self.file_path = file_path
        self.offset_rows = offset_rows

        self.symbol_token_map = {
            "HDFCBANK": "1333", "ICICIBANK": "4963", "AXISBANK": "5900", "KOTAKBANK": "1922",
            "SBIN": "3045", "INDUSINDBK": "5258", "BANDHANBNK": "2263", "PNB": "10666",
            "IDFCFIRSTB": "11184", "AUBANK": "21238", "FEDERALBNK": "1023", "BANKBARODA": "4668"
        }
        self.bank_nifty_stocks = list(self.symbol_token_map.keys())
        self.weight_map = {}
        self.last_weightage_fetch = None

        self.smartApi = SmartConnect(self.api_key)
        self.authenticate()
        self.wb, self.sheet = self.initialize_excel()

    def get_worksheet(self):
        import win32com.client
        excel = win32com.client.Dispatch("Excel.Application")
        excel.Visible = True
        if not os.path.exists(self.file_path):
            wb = excel.Workbooks.Add()
            ws = wb.Worksheets(1)
            wb.SaveAs(self.file_path)
        else:
            wb = excel.Workbooks.Open(self.file_path)
            ws = wb.Worksheets(1)
        return ws, wb

    def authenticate(self):
        try:
            totp = pyotp.TOTP(self.token).now()
        except Exception as e:
            logger.error("Invalid Token: The provided token is not valid.")
            raise e

        data = self.smartApi.generateSession(self.username, self.pwd, totp)
        if data['status'] == False:
            logger.error(data)
            raise Exception("Authentication failed")
        else:
            self.authToken = data['data']['jwtToken']
            self.refreshToken = data['data']['refreshToken']
            self.feedToken = self.smartApi.getfeedToken()
            self.profile = self.smartApi.getProfile(self.refreshToken)
            self.smartApi.generateToken(self.refreshToken)

    def get_banknifty_weightage(self):
        if self.last_weightage_fetch == datetime.now().date():
            return

        url = "https://www.smart-investing.in/indices-bse-nse.php?index=BANKNIFTY"
        try:
            tables = pd.read_html(url)
            for table in tables:
                cols = [col.lower() for col in table.columns.astype(str)]
                if "company" in cols and any("weight" in c for c in cols):
                    table.columns = [col.strip() for col in table.columns]
                    table = table.rename(columns={
                        table.columns[0]: "Bank Name",
                        table.columns[1]: "Weightage (%)"
                    })
                    table["Weightage (%)"] = table["Weightage (%)"].str.replace("%", "").astype(float)

                    alias_map = {
                        "HDFC BANK": "HDFCBANK",
                        "ICICI BANK": "ICICIBANK",
                        "AXIS BANK": "AXISBANK",
                        "KOTAK MAHINDRA BANK": "KOTAKBANK",
                        "STATE BANK OF INDIA": "SBIN",
                        "INDUSIND BANK": "INDUSINDBK",
                        "BANDHAN BANK": "BANDHANBNK",
                        "PUNJAB NATIONAL BANK": "PNB",
                        "IDFC FIRST BANK": "IDFCFIRSTB",
                        "AU SMALL FINANCE BANK": "AUBANK",
                        "THE FEDERAL BANK": "FEDERALBNK",
                        "BANK OF BARODA": "BANKBARODA"
                    }

                    self.weight_map.clear()
                    for _, row in table.iterrows():
                        full_name = row["Bank Name"].upper().replace(" LTD", "").strip()
                        symbol = alias_map.get(full_name, None)
                        if symbol:
                            self.weight_map[symbol] = row["Weightage (%)"]
                    self.last_weightage_fetch = datetime.now().date()
                    return
            print("Weightage table not found")
        except Exception as e:
            print("Error fetching weightage:", e)

    def initialize_excel(self):
        excel = win32com.client.gencache.EnsureDispatch("Excel.Application")
        excel.Visible = True

        if not os.path.exists(self.file_path):
            wb = excel.Workbooks.Add()
            sheet = wb.Worksheets(1)
            headers = ["Bank", "LTP", "Volume", "Change %", "Status", "Weightage"]
            for col, header in enumerate(headers, 1):
                sheet.Cells(1 + self.offset_rows, col).Value = header
            wb.SaveAs(self.file_path)
            return wb, sheet

        for wb in excel.Workbooks:
            if wb.FullName.lower() == self.file_path.lower():
                return wb, wb.Worksheets(1)
        try:
            wb = excel.Workbooks.Open(self.file_path)
            return wb, wb.Worksheets(1)
        except:
            wb = excel.Workbooks.Add()
            sheet = wb.Worksheets(1)
            headers = ["Bank", "LTP", "Volume", "Change %", "Status", "Weightage"]
            for col, header in enumerate(headers, 1):
                sheet.Cells(1 + self.offset_rows, col).Value = header
            wb.SaveAs(self.file_path)
            return wb, sheet

    def get_status(self, open, close):
        if (close > open):
            return "Bullish"
        elif (close < open):
            return "Bearish"
        return "Neutral"

    def update_excel(self):
        ws, wb = self.get_worksheet()

        def get_last_trading_day(current_date):
            last_trading_day = current_date - timedelta(days=1)
            if current_date.weekday() == 0:
                last_trading_day = current_date - timedelta(days=3)
            elif current_date.weekday() == 6:
                last_trading_day = current_date - timedelta(days=2)
            elif current_date.weekday() == 5:
                last_trading_day = current_date - timedelta(days=1)
            return last_trading_day

        now = datetime.now()
        today_open = now.replace(hour=9, minute=15, second=0, microsecond=0)
        market_close = now.replace(hour=15, minute=30, second=0, microsecond=0)

        if now.weekday() >= 5:
            print("⚠️ Market is closed on Saturday and Sunday.")
            last_trading_day = get_last_trading_day(now)
            from_date = last_trading_day.replace(hour=14, minute=30).strftime("%Y-%m-%d %H:%M")
            to_date = last_trading_day.replace(hour=15, minute=30).strftime("%Y-%m-%d %H:%M")
        else:
            if now < today_open:
                print("⚠️ Market has not opened yet. Try again after 9:15 AM.")
                last_trading_day = get_last_trading_day(now)
                from_date = last_trading_day.replace(hour=14, minute=30).strftime("%Y-%m-%d %H:%M")
                to_date = last_trading_day.replace(hour=15, minute=30).strftime("%Y-%m-%d %H:%M")
            elif now > market_close:
                print("⚠️ Market is closed for the day.")
                from_date = (market_close - timedelta(hours=1)).strftime("%Y-%m-%d %H:%M")
                to_date = market_close.strftime("%Y-%m-%d %H:%M")
            else:
                from_date = (now - timedelta(hours=1)).strftime("%Y-%m-%d %H:%M")
                to_date = now.strftime("%Y-%m-%d %H:%M")

        self.get_banknifty_weightage()
        # ws.UsedRange.Clear()
        headers = ["Bank", "LTP", "Volume", "Change %", "Status", "Weightage"]
        for col, header in enumerate(headers, 1):
            ws.Cells(1 + self.offset_rows, col).Value = header

        row_index = 2 + self.offset_rows
        for stock in self.bank_nifty_stocks:
            try:
                histParam = {
                    "exchange": "NSE",
                    "symboltoken": self.symbol_token_map[stock],
                    "interval": "ONE_MINUTE",
                    "fromdate": from_date,
                    "todate": to_date
                }
                response = self.smartApi.getCandleData(histParam)
                if response['status'] and response['data']:
                    candle = response['data'][-1]
                    ltp = candle[4]
                    volume = candle[5]
                    change_percent = ((candle[4] - candle[1]) / candle[1]) * 100
                    status = self.get_status(candle[1], candle[4]) 
                    weight = self.weight_map.get(stock.upper(), "")
                    ws.Cells(row_index, 1).Value = stock
                    ws.Cells(row_index, 2).Value = ltp
                    ws.Cells(row_index, 3).Value = volume
                    ws.Cells(row_index, 4).Value = round(change_percent, 2)
                    ws.Cells(row_index, 5).Value = status
                    ws.Cells(row_index, 6).Value = weight
                    row_index += 1
                else:
                    print(f"⚠️ Failed to get {stock} ONE_MINUTE data:", response)
            except Exception as e:
                print(f"❌ Error fetching {stock} data:", e)

        ws.Cells(row_index + 1, 1).Value = "Data Fetched At"
        ws.Cells(row_index + 1, 2).Value = to_date

        wb.Save()
        print(f"✅ Bank Nifty data updated in Excel at {datetime.now().strftime('%H:%M:%S')}")

    def run(self, interval_sec=60):
        try:
            while True:
                self.update_excel()
                time.sleep(interval_sec)
        except KeyboardInterrupt:
            print("Stopped by user.")
        except Exception as e:
            print("Unexpected error:", e)

class IndicesDashboard:
    def __init__(self, api_key, username, pwd, token, file_path):
        self.api_key = api_key
        self.username = username
        self.pwd = pwd
        self.token = token
        self.smartApi = SmartConnect(self.api_key)
        self.authenticate()
        self.file_path = file_path
        self.time_intervals = [
            "ONE_MINUTE", "THREE_MINUTE", "FIVE_MINUTE",
            "FIFTEEN_MINUTE", "THIRTY_MINUTE", "ONE_HOUR"
        ]
        self.instruments = {
            "BANKNIFTY": {"token": "99926009", "exchange": "NSE"},
            "BANKNIFTY FUTURE": {"token": "56782", "exchange": "NFO"},
            "NIFTY": {"token": "99926000", "exchange": "NSE"},
            "INDIA VIX": {"token": "99926017", "exchange": "NSE"}
        }
        self.interval_mapping = {
            "ONE_MINUTE": "1min",
            "THREE_MINUTE": "3min",
            "FIVE_MINUTE": "5min",
            "FIFTEEN_MINUTE": "15min",
            "THIRTY_MINUTE": "30min",
            "ONE_HOUR": "1hr"
        }
        self.setup_excel_structure()

    def get_latest_banknifty_future(self):
        """
        Fetches the latest BANKNIFTY FUTURE token, symbol, expiry, and exchange segment.
        Returns a dict: {"token": ..., "symbol": ..., "expiry": ..., "exch_seg": ...}
        """
        import requests
        import pandas as pd

        url = 'https://margincalculator.angelone.in/OpenAPI_File/files/OpenAPIScripMaster.json'
        data = requests.get(url).json()
        df = pd.DataFrame(data)

        # Filter for BANKNIFTY futures (exclude options)
        banknifty_futures = df[df['symbol'].str.contains(r'^BANKNIFTY.*FUT', na=False)]
        # Get the latest expiry (sort by expiry descending)
        banknifty_futures = banknifty_futures.sort_values('expiry', ascending=False)
        if not banknifty_futures.empty:
            row = banknifty_futures.iloc[0]
            return {
                "token": str(row['token']),
                "symbol": row['symbol'],
                "expiry": row['expiry'],
                "exch_seg": row['exch_seg']
            }
        else:
            return None

    def clear_dashboard(self):
        ws, wb = self.get_worksheet()
        ws.UsedRange.Clear()
        wb.Save()
        print("Dashboard cleared.")

    def authenticate(self):
        try:
            totp = pyotp.TOTP(self.token).now()
        except Exception as e:
            logger.error("Invalid Token: The provided token is not valid.")
            raise e
        data = self.smartApi.generateSession(self.username, self.pwd, totp)
        if data['status'] == False:
            logger.error(data)
            raise Exception("Authentication failed")
        else:
            self.authToken = data['data']['jwtToken']
            self.refreshToken = data['data']['refreshToken']
            self.feedToken = self.smartApi.getfeedToken()
            self.profile = self.smartApi.getProfile(self.refreshToken)
            self.smartApi.generateToken(self.refreshToken)

    def get_worksheet(self):
        import win32com.client
        excel = win32com.client.gencache.EnsureDispatch("Excel.Application")
        excel.Visible = True
        if not os.path.exists(self.file_path):
            wb = excel.Workbooks.Add()
            ws = wb.Worksheets(1)
            wb.SaveAs(self.file_path)
        else:
            wb = excel.Workbooks.Open(self.file_path)
            ws = wb.Worksheets(1)
        return ws, wb
    
    def initialize_excel(self):
        excel = win32com.client.gencache.EnsureDispatch("Excel.Application")
        excel.Visible = True
        if os.path.exists(self.file_path):
            wb = excel.Workbooks.Open(self.file_path)
            print(f"Opened existing workbook: {self.file_path}")
        else:
            wb = excel.Workbooks.Add()
            wb.SaveAs(self.file_path)
            print(f"Created new workbook: {self.file_path}")
        ws = wb.Sheets(1)
        self.setup_excel_structure()
        return excel, wb, ws

    def setup_excel_structure(self):
        ws, wb = self.get_worksheet()
        ws.Name = "Indices Dashboard"
        ws.Range("A1").Value = f"Date: {datetime.now().strftime('%d-%m-%Y')}"
        ws.Range("A2").Value = f"Time: {datetime.now().strftime('%H:%M')}"
        headers = ["", "", "1min", "3min", "5min", "15min", "30min", "1hrs"]
        for col_idx, header in enumerate(headers, 1):
            ws.Cells(4, col_idx).Value = header
        row_labels = {6: "A", 8: "B", 10: "C", 12: "D", 14: "F"}
        indice_names = {6: "BANKNIFTY", 8: "BANKNIFTY FUTURE", 10: "NIFTY", 12: "GIFT NIFTY", 14: "VIX"}
        for col in range(2, 9):
            ws.Columns(col).ColumnWidth = 20
            ws.Columns(col).WrapText = True
        for row, label in row_labels.items():
            ws.Cells(row, 1).Value = label
        for row, label in indice_names.items():
            ws.Cells(row, 2).Value = label
        gradient_pairs = [6, 8, 10, 12, 14]
        base_color = 0xD3D3D3
        def darken_color(hex_color, step):
            r = (hex_color & 0xFF0000) >> 16
            g = (hex_color & 0x00FF00) >> 8
            b = (hex_color & 0x0000FF)
            r = max(0, r - step)
            g = max(0, g - step)
            b = max(0, b - step)
            return (r << 16) + (g << 8) + b
        current_color = base_color
        for top_row in gradient_pairs:
            for col in range(1, 11):
                ws.Cells(top_row, col).Interior.Color = current_color
                ws.Cells(top_row + 1, col).Interior.Color = current_color
            current_color = darken_color(current_color, 15)
        wb.Save()

    def fetch_candle_data(self, symbol, token, exchange, interval):
        now = datetime.now()
        market_open = now.replace(hour=9, minute=15, second=0, microsecond=0)
        market_close = now.replace(hour=15, minute=30, second=0, microsecond=0)
        def get_last_trading_day(current_date):
            last_trading_day = current_date - timedelta(days=1)
            if current_date.weekday() == 0:
                last_trading_day = current_date - timedelta(days=3)
            elif current_date.weekday() == 6:
                last_trading_day = current_date - timedelta(days=2)
            elif current_date.weekday() == 5:
                last_trading_day = current_date - timedelta(days=1)
            return last_trading_day
        if now.weekday() >= 5:
            last_trading_day = get_last_trading_day(now)
            from_date = last_trading_day.replace(hour=14, minute=30).strftime("%Y-%m-%d %H:%M")
            to_date = last_trading_day.replace(hour=15, minute=30).strftime("%Y-%m-%d %H:%M")
        else:
            if now < market_open:
                last_trading_day = get_last_trading_day(now)
                from_date = last_trading_day.replace(hour=14, minute=30).strftime("%Y-%m-%d %H:%M")
                to_date = last_trading_day.replace(hour=15, minute=30).strftime("%Y-%m-%d %H:%M")
            elif now > market_close:
                from_date = (market_close - timedelta(hours=1)).strftime("%Y-%m-%d %H:%M")
                to_date = market_close.strftime("%Y-%m-%d %H:%M")
            else:
                from_date = (now - timedelta(hours=1)).strftime("%Y-%m-%d %H:%M")
                to_date = now.strftime("%Y-%m-%d %H:%M")
        params = {
            "exchange": exchange,
            "symboltoken": token,
            "interval": interval,
            "fromdate": from_date,
            "todate": to_date
        }
        try:
            response = self.smartApi.getCandleData(params)
            if response['status'] and response['data']:
                data = response['data']
                latest = data[-1:]
                df = pd.DataFrame(latest, columns=["Datetime", "Open", "High", "Low", "Close", "Volume"])
                df["Symbol"] = symbol
                df["Interval"] = interval
                return df
            else:
                print(f"⚠️ No candle data for {symbol} ({interval})")
                return pd.DataFrame()
        except Exception as e:
            print(f"❌ Error fetching {symbol} [{interval}]: {e}")
            return pd.DataFrame()

    def fetch_and_process_data(self):
        final_df = pd.DataFrame()
        for symbol, info in self.instruments.items():
            for interval in self.time_intervals:
                df = self.fetch_candle_data(symbol, info["token"], info["exchange"], interval)
                final_df = pd.concat([final_df, df], ignore_index=True)
        final_df = final_df[["Symbol", "Interval", "Datetime", "Open", "High", "Low", "Close", "Volume"]]
        final_df.sort_values(by=["Symbol", "Interval", "Datetime"], inplace=True)
        return final_df

    def calculate_sentiment(self, df):
        
        def sentiment_logic(row):
            symbol = row["Symbol"]
            close_price = row["Close"]
            open_price = row["Open"]

            if (open_price < close_price):
                sentiment = f"Bullish"
            elif (open_price > close_price):
                sentiment = f"Bearish"
            else:
                sentiment = f"Neutral"

            return sentiment

        df["Sentiment"] = df.apply(sentiment_logic, axis=1)
        df["Interval"] = df["Interval"].map(self.interval_mapping)
        return df

    def update_excel(self, df):
        ws, wb = self.get_worksheet()
        cell_mapping = {
            "BANKNIFTY": {"1min": "C6", "3min": "D6", "5min": "E6", "15min": "F6", "30min": "G6", "1hr": "H6"},
            "BANKNIFTY FUTURE": {"1min": "C8", "3min": "D8", "5min": "E8", "15min": "F8", "30min": "G8", "1hr": "H8"},
            "NIFTY": {"1min": "C10", "3min": "D10", "5min": "E10", "15min": "F10", "30min": "G10", "1hr": "H10"},
            "INDIA VIX": {"1min": "C14", "3min": "D14", "5min": "E14", "15min": "F14", "30min": "G14", "1hr": "H14"}
        }
        ws.Range("A1").Value = f"Date: {datetime.now().strftime('%d-%m-%Y')}"
        ws.Range("A2").Value = f"Time: {datetime.now().strftime('%H:%M')}"
        for symbol in cell_mapping.keys():
            for interval, cell in cell_mapping[symbol].items():
                try:
                    sentiment = df[(df["Symbol"] == symbol) & (df["Interval"] == interval)]["Sentiment"].iloc[0]
                except IndexError:
                    print(f"Warning: No sentiment data for {symbol} ({interval})")
                    continue
                ws.Range(cell).Value = sentiment
                if "bullish" in sentiment.lower():
                    ws.Range(cell).Font.Color = 0x008000  # Green
                elif "bearish" in sentiment.lower():
                    ws.Range(cell).Font.Color = 0x0000FF  # Blue
                else:
                    ws.Range(cell).Font.Color = 0x000000  # Black
        wb = ws.Parent
        wb.Save()
        print("Excel file updated successfully.")

    def run(self):
        try:
            while True:
                try:
                    df = self.fetch_and_process_data()
                    df = self.calculate_sentiment(df)
                    self.update_excel(self.ws, df)
                    print(f"Data updated at {datetime.now().strftime('%H:%M:%S')}")
                except Exception as e:
                    print(f"Error during data update: {str(e)}")
                    if isinstance(e, requests.exceptions.ConnectionError):
                        print("Connection error detected. Retrying in 60 seconds...")
                time.sleep(60)
        except KeyboardInterrupt:
            print("Script interrupted by user.")
            try:
                self.wb.Save()
                self.wb.Close()
                self.excel.Quit()
                print("Excel application closed successfully.")
            except Exception as e:
                print(f"Error closing Excel: {str(e)}")
        except Exception as e:
            print(f"Fatal error: {str(e)}")
            try:
                self.wb.Close()
                self.excel.Quit()
            except:
                pass

# %%
file_path = r"C:\Users\jaiad\Pro T\Final_draft1\banknifty_dashboard.xlsx"

banknifty_args = {
    "api_key": '3tA3noq3',
    "username": 'AAAF620196',
    "pwd": '0054',
    "token": 'YS4MOR7OUZEHGNV3VFOQ5TVMRE',
    "file_path": file_path,
    "offset_rows": 15
}
indices_args = {
    "api_key": '3tA3noq3',
    "username": 'AAAF620196',
    "pwd": '0054',
    "token": 'YS4MOR7OUZEHGNV3VFOQ5TVMRE',
    "file_path": file_path
}


class DashboardIntegrator:
    def __init__(
        self,
        banknifty_args,
        indices_args,
        banknifty_interval=30
    ):
        self.banknifty_dashboard = BankNiftyDashboard(**banknifty_args)
        self.indices_dashboard = IndicesDashboard(**indices_args)
        self.indices_dashboard.clear_dashboard()
        self.indices_dashboard.setup_excel_structure()
        self.banknifty_interval = banknifty_interval
        #self.niftyupdater = OptionChainUpdaterCOM(file_path=file_path)
        #self.bankniftyupdater = BankOptionChainUpdaterCOM(file_path=file_path)

    def run(self):

        try:
            while True:
                try:
                    print("Updating Indices Dashboard...")
                    df = self.indices_dashboard.fetch_and_process_data()
                    df = self.indices_dashboard.calculate_sentiment(df)
                    self.indices_dashboard.update_excel(df)
                    print("Updating BankNifty Dashboard...")
                    self.banknifty_dashboard.update_excel()
                    print(f"Both dashboards updated at {datetime.now().strftime('%H:%M:%S')}")
                    # self.bankniftyupdater.run()
                    # self.niftyupdater.run()
                except Exception as e:
                    print(f"Error during update: {str(e)}")
                time.sleep(self.banknifty_interval)
        except KeyboardInterrupt:
            print("Stopped by user.")
        except Exception as e:
            print("Unexpected error:", e)

integrator = DashboardIntegrator(banknifty_args, indices_args, banknifty_interval=30)
integrator.run()

# %%
from SmartApi.smartConnect import SmartConnect
import pyotp, time
from datetime import datetime, timedelta

args = {
    "api_key": '3tA3noq3',
    "username": 'AAAF620196',
    "pwd": '0054',
    "token": 'YS4MOR7OUZEHGNV3VFOQ5TVMRE',
}

smartApi = SmartConnect(args["api_key"])
try:
    totp = pyotp.TOTP(args["token"]).now()
except Exception as e:
    logger.error("Invalid Token: The provided token is not valid.")
    raise e
data = smartApi.generateSession(args["username"], args["pwd"], totp)
print(data)
if data['status'] == False:
    logger.error(data)
    raise Exception("Authentication failed")
else:
    authToken = data['data']['jwtToken']
    refreshToken = data['data']['refreshToken']
    feedToken = smartApi.getfeedToken()
    profile = smartApi.getProfile(refreshToken)
    smartApi.generateToken(refreshToken)


# Search for BANKNIFTY futures in NFO and get the first tradingsymbol and symboltoken
search_result = smartApi.searchScrip("NFO", "BANKNIFTY")
first_data = search_result["data"][0]
tradingsymbol = first_data["tradingsymbol"]
symboltoken = first_data["symboltoken"].split()[0]
print("Exchange:", "NFO")
print("Tradingsymbol:", tradingsymbol)
print("Symboltoken:", symboltoken)

# Now get the full quote (LTP, OI, etc.) for this token
exchangeTokens = {"NFO": [symboltoken]}
result = smartApi.getMarketData('FULL', exchangeTokens)
print(result)
# Out:
# [I 250802 19:33:01 smartConnect:124] in pool
# {'status': True, 'message': 'SUCCESS', 'errorcode': '', 'data': {'clientcode': 'AAAF620196', 'name': 'A JAIADITHYA', 'email': '', 'mobileno': '', 'exchanges': ['nse_fo', 'nse_cm', 'cde_fo', 'ncx_fo', 'bse_fo', 'bse_cm', 'mcx_fo'], 'products': ['MARGIN', 'MIS', 'NRML', 'CNC', 'CO', 'BO'], 'lastlogintime': '', 'broker': '', 'jwtToken': 'Bearer eyJhbGciOiJIUzUxMiJ9.....1pqt_OV1WwwoWqDoYq1080uXnd5Ot74oN06yu6PKovIshfKqAtczfxRJgGC5oy6I37HLTLS6UqACcLKDj4Jy7w', 'refreshToken': 'eyJhbGciOiJIUzUxMiJ9.....HNlkzbfe7ls3IeDH958LfhNG3XANyelzaZ-A_fPvsPw28JHNMgpSaZ5fFjGhZTOCV39cf-Op-Gl3yS4MsUvWhw', 'feedToken': 'eyJhbGciOiJIUzUxMiJ9.eyJ1c2VybmFtZSI6IkFBQUY2MjAxOTYiLCJpYXQiOjE3NTQxNDMzODQsImV4cCI6MTc1NDIyOTc4NH0.qjoYHRIM3K_ahyb6qBCrhMKsmkpnBrv0LMAkGOU2AB5BCh-O1M_qYHfvkcVaP66tmP3gMbRMQ-WZA8UhCl22lg'}}
# [I 250802 19:33:07 smartConnect:496] Search successful. Found 2300 trading symbols for the given query:
#     1. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2528OCT25FUT, symboltoken: 64100 52145
#     2. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2530SEP25FUT, symboltoken: 64100 52995
#     3. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2533000CE, symboltoken: 65252
#     4. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2533000PE, symboltoken: 65253
#     5. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2533500CE, symboltoken: 65262
#     6. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2533500PE, symboltoken: 65263
#     7. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2534000CE, symboltoken: 65264
#     8. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2534000PE, symboltoken: 65265
#     9. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2534500CE, symboltoken: 65268
#     10. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2534500PE, symboltoken: 65269
#     11. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2535000CE, symboltoken: 65270
#     12. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2535000PE, symboltoken: 65271
#     13. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2535500CE, symboltoken: 65272
#     14. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2535500PE, symboltoken: 65273
#     15. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2536000CE, symboltoken: 65314
#     16. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2536000PE, symboltoken: 65315
#     17. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2536500CE, symboltoken: 65316
#     18. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2536500PE, symboltoken: 65317
#     19. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2537000CE, symboltoken: 65331
#     20. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2537000PE, symboltoken: 65332
#     21. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2537500CE, symboltoken: 65333
#     22. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2537500PE, symboltoken: 65334
#     23. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2538000CE, symboltoken: 65335
#     24. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2538000PE, symboltoken: 65336
#     25. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2538500CE, symboltoken: 65349
#     26. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2538500PE, symboltoken: 65350
#     27. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2539000CE, symboltoken: 65351
#     28. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2539000PE, symboltoken: 65352
#     29. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2539500CE, symboltoken: 65353
#     30. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2539500PE, symboltoken: 65354
#     31. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2540000CE, symboltoken: 65360
#     32. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2540000PE, symboltoken: 65361
#     33. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2540500CE, symboltoken: 65389
#     34. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2540500PE, symboltoken: 65390
#     35. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2540600CE, symboltoken: 65501
#     36. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2540600PE, symboltoken: 65528
#     37. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2540700CE, symboltoken: 65529
#     38. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2540700PE, symboltoken: 65530
#     39. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2540800CE, symboltoken: 65531
#     40. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2540800PE, symboltoken: 65532
#     41. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2540900CE, symboltoken: 65533
#     42. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2540900PE, symboltoken: 65552
#     43. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541000CE, symboltoken: 65553
#     44. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541000PE, symboltoken: 65554
#     45. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541100CE, symboltoken: 65555
#     46. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541100PE, symboltoken: 65556
#     47. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541200CE, symboltoken: 65557
#     48. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541200PE, symboltoken: 65558
#     49. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541300CE, symboltoken: 65559
#     50. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541300PE, symboltoken: 65560
#     51. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541400CE, symboltoken: 65561
#     52. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541400PE, symboltoken: 65562
#     53. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541500CE, symboltoken: 65563
#     54. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541500PE, symboltoken: 65564
#     55. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541600CE, symboltoken: 65569
#     56. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541600PE, symboltoken: 65570
#     57. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541700CE, symboltoken: 65571
#     58. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541700PE, symboltoken: 65599
#     59. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541800CE, symboltoken: 65600
#     60. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541800PE, symboltoken: 65620
#     61. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541900CE, symboltoken: 65621
#     62. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2541900PE, symboltoken: 65622
#     63. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542000CE, symboltoken: 65623
#     64. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542000PE, symboltoken: 65628
#     65. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542100CE, symboltoken: 65629
#     66. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542100PE, symboltoken: 65634
#     67. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542200CE, symboltoken: 65635
#     68. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542200PE, symboltoken: 65639
#     69. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542300CE, symboltoken: 65640
#     70. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542300PE, symboltoken: 65647
#     71. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542400CE, symboltoken: 65689
#     72. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542400PE, symboltoken: 65690
#     73. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542500CE, symboltoken: 65691
#     74. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542500PE, symboltoken: 65692
#     75. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542600CE, symboltoken: 65693
#     76. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542600PE, symboltoken: 65694
#     77. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542700CE, symboltoken: 65695
#     78. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542700PE, symboltoken: 65701
#     79. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542800CE, symboltoken: 65702
#     80. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542800PE, symboltoken: 65710
#     81. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542900CE, symboltoken: 65711
#     82. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2542900PE, symboltoken: 65712
#     83. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543000CE, symboltoken: 65713
#     84. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543000PE, symboltoken: 65714
#     85. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543100CE, symboltoken: 65715
#     86. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543100PE, symboltoken: 65716
#     87. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543200CE, symboltoken: 65717
#     88. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543200PE, symboltoken: 65718
#     89. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543300CE, symboltoken: 65719
#     90. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543300PE, symboltoken: 65724
#     91. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543400CE, symboltoken: 65725
#     92. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543400PE, symboltoken: 65726
#     93. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543500CE, symboltoken: 65727
#     94. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543500PE, symboltoken: 65728
#     95. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543600CE, symboltoken: 65729
#     96. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543600PE, symboltoken: 65730
#     97. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543700CE, symboltoken: 65731
#     98. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543700PE, symboltoken: 65732
#     99. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543800CE, symboltoken: 65733
#     100. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543800PE, symboltoken: 65734
#     101. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543900CE, symboltoken: 65735
#     102. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2543900PE, symboltoken: 65736
#     103. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544000CE, symboltoken: 65737
#     104. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544000PE, symboltoken: 65738
#     105. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544100CE, symboltoken: 65739
#     106. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544100PE, symboltoken: 65740
#     107. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544200CE, symboltoken: 65741
#     108. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544200PE, symboltoken: 65742
#     109. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544300CE, symboltoken: 65743
#     110. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544300PE, symboltoken: 65744
#     111. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544400CE, symboltoken: 65745
#     112. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544400PE, symboltoken: 65746
#     113. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544500CE, symboltoken: 65747
#     114. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544500PE, symboltoken: 65748
#     115. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544600CE, symboltoken: 65749
#     116. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544600PE, symboltoken: 65750
#     117. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544700CE, symboltoken: 65751
#     118. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544700PE, symboltoken: 65752
#     119. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544800CE, symboltoken: 65753
#     120. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544800PE, symboltoken: 65754
#     121. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544900CE, symboltoken: 65755
#     122. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2544900PE, symboltoken: 65756
#     123. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545000CE, symboltoken: 65757
#     124. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545000PE, symboltoken: 65758
#     125. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545100CE, symboltoken: 65759
#     126. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545100PE, symboltoken: 65760
#     127. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545200CE, symboltoken: 65761
#     128. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545200PE, symboltoken: 65762
#     129. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545300CE, symboltoken: 65763
#     130. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545300PE, symboltoken: 65764
#     131. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545400CE, symboltoken: 65765
#     132. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545400PE, symboltoken: 65766
#     133. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545500CE, symboltoken: 65767
#     134. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545500PE, symboltoken: 65768
#     135. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545600CE, symboltoken: 65769
#     136. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545600PE, symboltoken: 65770
#     137. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545700CE, symboltoken: 65771
#     138. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545700PE, symboltoken: 65772
#     139. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545800CE, symboltoken: 65773
#     140. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545800PE, symboltoken: 65774
#     141. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545900CE, symboltoken: 65775
#     142. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2545900PE, symboltoken: 65776
#     143. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546000CE, symboltoken: 65777
#     144. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546000PE, symboltoken: 65778
#     145. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546100CE, symboltoken: 65779
#     146. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546100PE, symboltoken: 65780
#     147. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546200CE, symboltoken: 65781
#     148. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546200PE, symboltoken: 65782
#     149. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546300CE, symboltoken: 65785
#     150. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546300PE, symboltoken: 65788
#     151. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546400CE, symboltoken: 65789
#     152. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546400PE, symboltoken: 65790
#     153. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546500CE, symboltoken: 65791
#     154. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546500PE, symboltoken: 65806
#     155. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546600CE, symboltoken: 65807
#     156. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546600PE, symboltoken: 65827
#     157. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546700CE, symboltoken: 65828
#     158. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546700PE, symboltoken: 65829
#     159. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546800CE, symboltoken: 65830
#     160. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546800PE, symboltoken: 65839
#     161. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546900CE, symboltoken: 65919
#     162. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2546900PE, symboltoken: 65920
#     163. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547000CE, symboltoken: 65921
#     164. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547000PE, symboltoken: 65922
#     165. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547100CE, symboltoken: 65923
#     166. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547100PE, symboltoken: 65924
#     167. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547200CE, symboltoken: 65925
#     168. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547200PE, symboltoken: 65926
#     169. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547300CE, symboltoken: 65927
#     170. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547300PE, symboltoken: 65928
#     171. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547400CE, symboltoken: 65929
#     172. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547400PE, symboltoken: 65930
#     173. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547500CE, symboltoken: 65931
#     174. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547500PE, symboltoken: 65932
#     175. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547600CE, symboltoken: 65933
#     176. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547600PE, symboltoken: 65934
#     177. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547700CE, symboltoken: 65935
#     178. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547700PE, symboltoken: 65936
#     179. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547800CE, symboltoken: 65970
#     180. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547800PE, symboltoken: 65973
#     181. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547900CE, symboltoken: 66031
#     182. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2547900PE, symboltoken: 66032
#     183. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548000CE, symboltoken: 66111
#     184. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548000PE, symboltoken: 66112
#     185. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548100CE, symboltoken: 66121
#     186. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548100PE, symboltoken: 66122
#     187. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548200CE, symboltoken: 66126
#     188. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548200PE, symboltoken: 66134
#     189. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548300CE, symboltoken: 66143
#     190. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548300PE, symboltoken: 66144
#     191. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548400CE, symboltoken: 66147
#     192. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548400PE, symboltoken: 66148
#     193. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548500CE, symboltoken: 66155
#     194. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548500PE, symboltoken: 66156
#     195. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548600CE, symboltoken: 66157
#     196. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548600PE, symboltoken: 66158
#     197. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548700CE, symboltoken: 66159
#     198. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548700PE, symboltoken: 66160
#     199. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548800CE, symboltoken: 66161
#     200. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548800PE, symboltoken: 66162
#     201. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548900CE, symboltoken: 66165
#     202. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2548900PE, symboltoken: 66166
#     203. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2549000CE, symboltoken: 66167
#     204. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2549000PE, symboltoken: 66168
#     205. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2549100CE, symboltoken: 66169
#     206. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2549100PE, symboltoken: 66170
#     207. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2549200CE, symboltoken: 66171
#     208. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2549200PE, symboltoken: 66172
#     209. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2549300CE, symboltoken: 66173
#     210. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2549300PE, symboltoken: 66174
#     211. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2549400CE, symboltoken: 66175
#     212. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2549400PE, symboltoken: 66176
#     213. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2549500CE, symboltoken: 66177
#     214. exchange: NFO, tradingsymbol: BANKNIFTY28AUG2
exchange: NFO, tradingsymbol: BANKNIFTY31MAR2667500PE, symboltoken: 58672
#     2289. exchange: NFO, tradingsymbol: BANKNIFTY31MAR2669000CE, symboltoken: 58673
#     2290. exchange: NFO, tradingsymbol: BANKNIFTY31MAR2669000PE, symboltoken: 58674
#     2291. exchange: NFO, tradingsymbol: BANKNIFTY31MAR2670500CE, symboltoken: 58676
#     2292. exchange: NFO, tradingsymbol: BANKNIFTY31MAR2670500PE, symboltoken: 58677
#     2293. exchange: NFO, tradingsymbol: BANKNIFTY31MAR2672000CE, symboltoken: 58678
#     2294. exchange: NFO, tradingsymbol: BANKNIFTY31MAR2672000PE, symboltoken: 58679
#     2295. exchange: NFO, tradingsymbol: BANKNIFTY31MAR2673500CE, symboltoken: 58680
#     2296. exchange: NFO, tradingsymbol: BANKNIFTY31MAR2673500PE, symboltoken: 58681
#     2297. exchange: NFO, tradingsymbol: BANKNIFTY31MAR2675000CE, symboltoken: 43936
#     2298. exchange: NFO, tradingsymbol: BANKNIFTY31MAR2675000PE, symboltoken: 43937
#     2299. exchange: NFO, tradingsymbol: BANKNIFTY31MAR2676500CE, symboltoken: 48785
#     2300. exchange: NFO, tradingsymbol: BANKNIFTY31MAR2676500PE, symboltoken: 48786
# Exchange: NFO
# Tradingsymbol: BANKNIFTY28AUG2528OCT25FUT
# Symboltoken: 64100
# {'status': True, 'message': 'SUCCESS', 'errorcode': '', 'data': {'fetched': [{'exchange': 'NFO', 'tradingSymbol': 'BANKNIFTY28AUG25FUT', 'symbolToken': '64100', 'ltp': 55794.2, 'open': 56200.0, 'high': 56249.8, 'low': 55730.0, 'close': 56194.0, 'lastTradeQty': 35, 'exchFeedTime': '02-Aug-2025 06:55:10', 'exchTradeTime': '01-Aug-2025 15:29:59', 'netChange': -399.8, 'percentChange': -0.71, 'avgPrice': 56002.66, 'tradeVolume': 1148875, 'opnInterest': 2117605, 'lowerCircuit': 50574.6, 'upperCircuit': 61813.4, 'totBuyQuan': 34895, 'totSellQuan': 83475, '52WeekLow': 0.0, '52WeekHigh': 58026.0, 'depth': {'buy': [{'price': 55796.4, 'quantity': 35, 'orders': 1}, {'price': 55794.8, 'quantity': 175, 'orders': 1}, {'price': 55791.4, 'quantity': 35, 'orders': 1}, {'price': 55791.0, 'quantity': 35, 'orders': 1}, {'price': 55790.2, 'quantity': 35, 'orders': 1}], 'sell': [{'price': 55811.0, 'quantity': 35, 'orders': 1}, {'price': 55812.6, 'quantity': 35, 'orders': 1}, {'price': 55819.0, 'quantity': 35, 'orders': 1}, {'price': 55820.0, 'quantity': 945, 'orders': 11}, {'price': 55820.6, 'quantity': 105, 'orders': 1}]}}], 'unfetched': []}}

# %%
from datetime import datetime

args = {
    "api_key": '3tA3noq3',
    "username": 'AAAF620196',
    "pwd": '0054',
    "token": 'YS4MOR7OUZEHGNV3VFOQ5TVMRE',
}

smartApi = SmartConnect(args["api_key"])
try:
    totp = pyotp.TOTP(args["token"]).now()
except Exception as e:
    logger.error("Invalid Token: The provided token is not valid.")
    raise e
data = smartApi.generateSession(args["username"], args["pwd"], totp)
if data['status'] == False:
    logger.error(data)
    raise Exception("Authentication failed")
else:
    authToken = data['data']['jwtToken']
    refreshToken = data['data']['refreshToken']
    feedToken = smartApi.getfeedToken()
    profile = smartApi.getProfile(refreshToken)
    smartApi.generateToken(refreshToken)

instruments = {
            "BANKNIFTY": {"token": "99926009", "exchange": "NSE"},
            "BANKNIFTY FUTURE": {"token": "56782", "exchange": "NFO"},
            "NIFTY": {"token": "99926000", "exchange": "NSE"},
            "INDIA VIX": {"token": "99926017", "exchange": "NSE"}
        }

def fetch_candle_data():
        now = datetime.now()
        market_open = now.replace(hour=9, minute=15, second=0, microsecond=0)
        market_close = now.replace(hour=15, minute=30, second=0, microsecond=0)
        def get_last_trading_day(current_date):
            last_trading_day = current_date - timedelta(days=1)
            if current_date.weekday() == 0:
                last_trading_day = current_date - timedelta(days=3)
            elif current_date.weekday() == 6:
                last_trading_day = current_date - timedelta(days=2)
            elif current_date.weekday() == 5:
                last_trading_day = current_date - timedelta(days=1)
            return last_trading_day
        if now.weekday() >= 5:
            last_trading_day = get_last_trading_day(now)
            from_date = last_trading_day.replace(hour=14, minute=30).strftime("%Y-%m-%d %H:%M")
            to_date = last_trading_day.replace(hour=15, minute=30).strftime("%Y-%m-%d %H:%M")
        else:
            if now < market_open:
                last_trading_day = get_last_trading_day(now)
                from_date = last_trading_day.replace(hour=14, minute=30).strftime("%Y-%m-%d %H:%M")
                to_date = last_trading_day.replace(hour=15, minute=30).strftime("%Y-%m-%d %H:%M")
            elif now > market_close:
                from_date = (market_close - timedelta(hours=1)).strftime("%Y-%m-%d %H:%M")
                to_date = market_close.strftime("%Y-%m-%d %H:%M")
            else:
                from_date = (now - timedelta(hours=1)).strftime("%Y-%m-%d %H:%M")
                to_date = now.strftime("%Y-%m-%d %H:%M")
        params = {
            "exchange": "NSE",
            "symboltoken": "99926009",
            "interval": "FIVE_MINUTE",
            "fromdate": from_date,
            "todate": to_date
        }
        
        response = smartApi.getCandleData(params)
        print(response['data'])
fetch_candle_data()
# Out:
# [I 250802 19:56:23 smartConnect:124] in pool
# [['2025-08-01T14:30:00+05:30', 55743.35, 55784.75, 55721.5, 55754.3, 0], ['2025-08-01T14:35:00+05:30', 55750.85, 55785.75, 55692.35, 55740.05, 0], ['2025-08-01T14:40:00+05:30', 55741.4, 55746.05, 55695.55, 55709.05, 0], ['2025-08-01T14:45:00+05:30', 55711.0, 55737.35, 55693.75, 55731.15, 0], ['2025-08-01T14:50:00+05:30', 55732.9, 55738.4, 55705.45, 55709.05, 0], ['2025-08-01T14:55:00+05:30', 55711.9, 55715.8, 55679.65, 55699.6, 0], ['2025-08-01T15:00:00+05:30', 55693.65, 55727.6, 55661.95, 55670.35, 0], ['2025-08-01T15:05:00+05:30', 55674.55, 55676.85, 55590.65, 55593.85, 0], ['2025-08-01T15:10:00+05:30', 55603.4, 55608.8, 55562.1, 55591.55, 0], ['2025-08-01T15:15:00+05:30', 55594.5, 55608.9, 55570.05, 55599.75, 0], ['2025-08-01T15:20:00+05:30', 55601.5, 55632.2, 55597.05, 55620.1, 0], ['2025-08-01T15:25:00+05:30', 55624.15, 55658.9, 55591.8, 55636.15, 0]]

# %% [markdown]
# # Instead of Futures have to search for Options

# %%
from SmartApi.smartConnect import SmartConnect
import pyotp, time
from datetime import datetime, timedelta

args = {
    "api_key": '3tA3noq3',
    "username": 'AAAF620196',
    "pwd": '0054',
    "token": 'YS4MOR7OUZEHGNV3VFOQ5TVMRE',
}

smartApi = SmartConnect(args["api_key"])
try:
    totp = pyotp.TOTP(args["token"]).now()
except Exception as e:
    logger.error("Invalid Token: The provided token is not valid.")
    raise e
data = smartApi.generateSession(args["username"], args["pwd"], totp)
print(data)
if data['status'] == False:
    logger.error(data)
    raise Exception("Authentication failed")
else:
    authToken = data['data']['jwtToken']
    refreshToken = data['data']['refreshToken']
    feedToken = smartApi.getfeedToken()
    profile = smartApi.getProfile(refreshToken)
    smartApi.generateToken(refreshToken)


# Search for BANKNIFTY futures in NFO and get the first tradingsymbol and symboltoken
search_result = smartApi.searchScrip("NFO", "BANKNIFTY")
first_data = search_result["data"][0]
tradingsymbol = first_data["tradingsymbol"]
symboltoken = first_data["symboltoken"].split()[0]
print("Exchange:", "NFO")
print("Tradingsymbol:", tradingsymbol)
print("Symboltoken:", symboltoken)

# Now get the full quote (LTP, OI, etc.) for this token
exchangeTokens = {"NFO": [symboltoken]}
result = smartApi.getMarketData('FULL', exchangeTokens)
print(result)
