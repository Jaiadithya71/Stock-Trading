# %%
import sys
import time
import pyotp
import pandas as pd
import win32com
import SmartApi
import logzero
import requests

print("Python:", sys.version)
print("time:", time.__doc__[:30] + "...")
# print("pyotp:", pyotp.__version__)
print("pandas:", pd.__version__)
print("win32com:", win32com.__gen_path__)
print("SmartApi:", SmartApi.__version__ if hasattr(SmartApi, '__version__') else "No __version__ attribute")
print("logzero:", logzero.__version__)
print("requests:", requests.__version__)
# Out:
# Python: 3.12.6 (tags/v3.12.6:a4a2d2b, Sep  6 2024, 20:11:23) [MSC v.1940 64 bit (AMD64)]
# time: This module provides various f...
# pandas: 2.2.3
# win32com: C:\Users\jaiad\AppData\Local\Temp\gen_py\3.12
# SmartApi: No __version__ attribute
# logzero: 1.7.0
# requests: 2.31.0

# %%
# !pip show Smartapi
# Out:
# DEPRECATION: Loading egg at c:\program files\python312\lib\site-packages\vboxapi-1.0-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Package(s) not found: Smartapi

# %%
import SmartApi

# %%
# !pip show smartapi-python==1.4.8
# Out:
# DEPRECATION: Loading egg at c:\program files\python312\lib\site-packages\vboxapi-1.0-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Package(s) not found: smartapi-python==1.4.8

# %%
from SmartApi import SmartConnect

# %%
import SmartApi
print(SmartApi.__file__)
# Out:
# C:\Users\jaiad\AppData\Roaming\Python\Python312\site-packages\SmartApi\__init__.py
