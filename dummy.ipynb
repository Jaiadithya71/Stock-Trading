# %%
import random
import requests
from pathlib import Path
import pprint

class OptionChainUpdaterCOM:
    def __init__(self, file_path: str):
        self.file_path = Path(file_path)
        self.summary_path = self.file_path.parent # "nifty_summary.json"
        self.headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36",
            "Accept": "application/json, text/plain, */*",
            "Referer": "https://www.nseindia.com/option-chain"
        }

    def fetch_data(self):
        random_suffix = random.randint(100000, 999999)
        oc_url = f"https://www.nseindia.com/api/option-chain-indices?symbol=NIFTY&c={random_suffix}"

        session = requests.Session()
        session.get("https://www.nseindia.com/option-chain", headers=self.headers)
        response = session.get(oc_url, headers=self.headers)

        if response.status_code != 200:
            raise Exception(f"Failed to fetch data. Status code: {response.status_code}")

        full_data = response.json()
        import pprint
        pp = pprint.PrettyPrinter(indent=2)
        pp.pprint(full_data)

a = OptionChainUpdaterCOM()
a.fetch_data()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 32
#      29         pp = pprint.PrettyPrinter(indent=2)
#      30         pp.pprint(full_data)
# ---> 32 a = OptionChainUpdaterCOM()
#      33 a.fetch_data()
#
# TypeError: OptionChainUpdaterCOM.__init__() missing 1 required positional argument: 'file_path'

# %%
import random
import requests
from pathlib import Path
import pprint

class OptionChainUpdaterCOM:
    def __init__(self, file_path: str = "dummy.xlsx"):
        self.file_path = Path(file_path)
        self.summary_path = self.file_path.parent  # "nifty_summary.json"
        self.headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36",
            "Accept": "application/json, text/plain, */*",
            "Referer": "https://www.nseindia.com/option-chain"
        }

    def fetch_data(self):
        random_suffix = random.randint(100000, 999999)
        oc_url = f"https://www.nseindia.com/api/option-chain-indices?symbol=NIFTY&c={random_suffix}"

        session = requests.Session()
        # Get cookies by visiting the main option chain page first
        session.get("https://www.nseindia.com/option-chain", headers=self.headers)
        response = session.get(oc_url, headers=self.headers)

        if response.status_code != 200:
            raise Exception(f"Failed to fetch data. Status code: {response.status_code}")

        full_data = response.json()
        pp = pprint.PrettyPrinter(indent=2)
        pp.pprint(full_data['filtered'])

# Usage example:
a = OptionChainUpdaterCOM()
a.fetch_data()
# Out:
# { 'CE': {'totOI': 2302668, 'totVol': 128890976},
#   'PE': {'totOI': 1542095, 'totVol': 124071510},
#   'data': [ { 'CE': { 'askPrice': 1905.75,
#                       'askQty': 75,
#                       'bidQty': 300,
#                       'bidprice': 1860.5,
#                       'change': -231.19999999999982,
#                       'changeinOpenInterest': -40,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE22600.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 1900,
#                       'openInterest': 37,
#                       'pChange': -10.848348348348342,
#                       'pchangeinOpenInterest': -51.94805194805195,
#                       'strikePrice': 22600,
#                       'totalBuyQuantity': 7050,
#                       'totalSellQuantity': 6750,
#                       'totalTradedVolume': 76,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 66750,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.45,
#                       'changeinOpenInterest': -26921,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE22600.00',
#                       'impliedVolatility': 46.49,
#                       'lastPrice': 0.05,
#                       'openInterest': 32714,
#                       'pChange': -90,
#                       'pchangeinOpenInterest': -45.1429529638635,
#                       'strikePrice': 22600,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 220575,
#                       'totalTradedVolume': 231835,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 22600},
#             { 'CE': { 'askPrice': 1864,
#                       'askQty': 225,
#                       'bidQty': 225,
#                       'bidprice': 1832.6,
#                       'change': -448.9499999999998,
#                       'changeinOpenInterest': 2,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE22650.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 1868.25,
#                       'openInterest': 4,
#                       'pChange': -19.37467633350595,
#                       'pchangeinOpenInterest': 100,
#                       'strikePrice': 22650,
#                       'totalBuyQuantity': 6675,
#                       'totalSellQuantity': 6375,
#                       'totalTradedVolume': 13,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 5475,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.4,
#                       'changeinOpenInterest': -5033,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE22650.00',
#                       'impliedVolatility': 45.33,
#                       'lastPrice': 0.05,
#                       'openInterest': 2563,
#                       'pChange': -88.8888888888889,
#                       'pchangeinOpenInterest': -66.25855713533439,
#                       'strikePrice': 22650,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 99450,
#                       'totalTradedVolume': 48816,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 22650},
#             { 'CE': { 'askPrice': 1814.3,
#                       'askQty': 225,
#                       'bidQty': 225,
#                       'bidprice': 1784.9,
#                       'change': 0,
#                       'changeinOpenInterest': 0,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE22700.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 1861.15,
#                       'openInterest': 1,
#                       'pChange': 0,
#                       'pchangeinOpenInterest': 0,
#                       'strikePrice': 22700,
#                       'totalBuyQuantity': 6525,
#                       'totalSellQuantity': 6375,
#                       'totalTradedVolume': 0,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 26325,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.35000000000000003,
#                       'changeinOpenInterest': -3449,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE22700.00',
#                       'impliedVolatility': 44.17,
#                       'lastPrice': 0.05,
#                       'openInterest': 7955,
#                       'pChange': -87.5,
#                       'pchangeinOpenInterest': -30.243774114345843,
#                       'strikePrice': 22700,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 139275,
#                       'totalTradedVolume': 71980,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 22700},
#             { 'CE': { 'askPrice': 1764.2,
#                       'askQty': 225,
#                       'bidQty': 225,
#                       'bidprice': 1735.15,
#                       'change': 0,
#                       'changeinOpenInterest': 0,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE22750.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 2223.75,
#                       'openInterest': 2,
#                       'pChange': 0,
#                       'pchangeinOpenInterest': 0,
#                       'strikePrice': 22750,
#                       'totalBuyQuantity': 4500,
#                       'totalSellQuantity': 6675,
#                       'totalTradedVolume': 0,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 15600,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.35000000000000003,
#                       'changeinOpenInterest': -70,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE22750.00',
#                       'impliedVolatility': 43.01,
#                       'lastPrice': 0.05,
#                       'openInterest': 12377,
#                       'pChange': -87.5,
#                       'pchangeinOpenInterest': -0.5623845103237728,
#                       'strikePrice': 22750,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 118200,
#                       'totalTradedVolume': 100017,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 22750},
#             { 'CE': { 'askPrice': 1707,
#                       'askQty': 75,
#                       'bidQty': 300,
#                       'bidprice': 1693.55,
#                       'change': -232.5,
#                       'changeinOpenInterest': -700,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE22800.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 1700.05,
#                       'openInterest': 650,
#                       'pChange': -12.030736591550024,
#                       'pchangeinOpenInterest': -51.851851851851855,
#                       'strikePrice': 22800,
#                       'totalBuyQuantity': 6525,
#                       'totalSellQuantity': 6000,
#                       'totalTradedVolume': 1235,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 7500,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.6,
#                       'changeinOpenInterest': -3229,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE22800.00',
#                       'impliedVolatility': 41.85,
#                       'lastPrice': 0.05,
#                       'openInterest': 7607,
#                       'pChange': -92.3076923076923,
#                       'pchangeinOpenInterest': -29.798818752307124,
#                       'strikePrice': 22800,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 127050,
#                       'totalTradedVolume': 69560,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 22800},
#             { 'CE': { 'askPrice': 1662.65,
#                       'askQty': 225,
#                       'bidQty': 225,
#                       'bidprice': 1637.25,
#                       'change': 0,
#                       'changeinOpenInterest': 0,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE22850.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 2125.9,
#                       'openInterest': 3,
#                       'pChange': 0,
#                       'pchangeinOpenInterest': 0,
#                       'strikePrice': 22850,
#                       'totalBuyQuantity': 6525,
#                       'totalSellQuantity': 6675,
#                       'totalTradedVolume': 0,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 1050,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.6499999999999999,
#                       'changeinOpenInterest': 1151,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE22850.00',
#                       'impliedVolatility': 40.7,
#                       'lastPrice': 0.05,
#                       'openInterest': 1841,
#                       'pChange': -92.85714285714285,
#                       'pchangeinOpenInterest': 166.81159420289856,
#                       'strikePrice': 22850,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 130950,
#                       'totalTradedVolume': 31822,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 22850},
#             { 'CE': { 'askPrice': 1611.85,
#                       'askQty': 150,
#                       'bidQty': 225,
#                       'bidprice': 1585.45,
#                       'change': -357.6999999999998,
#                       'changeinOpenInterest': -1,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE22900.00',
#                       'impliedVolatility': 99.9,
#                       'lastPrice': 1700.5,
#                       'openInterest': 8,
#                       'pChange': -17.379263434068594,
#                       'pchangeinOpenInterest': -11.11111111111111,
#                       'strikePrice': 22900,
#                       'totalBuyQuantity': 6525,
#                       'totalSellQuantity': 6525,
#                       'totalTradedVolume': 1,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.1,
#                       'askQty': 1950,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.6,
#                       'changeinOpenInterest': -447,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE22900.00',
#                       'impliedVolatility': 41.64,
#                       'lastPrice': 0.1,
#                       'openInterest': 1857,
#                       'pChange': -85.71428571428572,
#                       'pchangeinOpenInterest': -19.401041666666668,
#                       'strikePrice': 22900,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 114900,
#                       'totalTradedVolume': 52648,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 22900},
#             { 'CE': { 'askPrice': 1564.8,
#                       'askQty': 225,
#                       'bidQty': 225,
#                       'bidprice': 1541.2,
#                       'change': 0,
#                       'changeinOpenInterest': 0,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE22950.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 1860,
#                       'openInterest': 5,
#                       'pChange': 0,
#                       'pchangeinOpenInterest': 0,
#                       'strikePrice': 22950,
#                       'totalBuyQuantity': 6825,
#                       'totalSellQuantity': 6375,
#                       'totalTradedVolume': 0,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 20700,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.7,
#                       'changeinOpenInterest': 1413,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE22950.00',
#                       'impliedVolatility': 38.38,
#                       'lastPrice': 0.05,
#                       'openInterest': 2203,
#                       'pChange': -93.33333333333333,
#                       'pchangeinOpenInterest': 178.86075949367088,
#                       'strikePrice': 22950,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 149175,
#                       'totalTradedVolume': 24832,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 22950},
#             { 'CE': { 'askPrice': 1502.35,
#                       'askQty': 225,
#                       'bidQty': 75,
#                       'bidprice': 1499.1,
#                       'change': -236.5,
#                       'changeinOpenInterest': -2153,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23000.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 1499.1,
#                       'openInterest': 2015,
#                       'pChange': -13.626411615579629,
#                       'pchangeinOpenInterest': -51.65547024952016,
#                       'strikePrice': 23000,
#                       'totalBuyQuantity': 13650,
#                       'totalSellQuantity': 8700,
#                       'totalTradedVolume': 3773,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 77625,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.6,
#                       'changeinOpenInterest': -3624,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE23000.00',
#                       'impliedVolatility': 37.23,
#                       'lastPrice': 0.05,
#                       'openInterest': 21375,
#                       'pChange': -92.3076923076923,
#                       'pchangeinOpenInterest': -14.496579863194528,
#                       'strikePrice': 23000,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 289950,
#                       'totalTradedVolume': 247559,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 23000},
#             { 'CE': { 'askPrice': 1464.05,
#                       'askQty': 225,
#                       'bidQty': 225,
#                       'bidprice': 1441.35,
#                       'change': -131.95000000000005,
#                       'changeinOpenInterest': -1,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23050.00',
#                       'impliedVolatility': 92.3,
#                       'lastPrice': 1549.45,
#                       'openInterest': 4,
#                       'pChange': -7.847626977518736,
#                       'pchangeinOpenInterest': -20,
#                       'strikePrice': 23050,
#                       'totalBuyQuantity': 6675,
#                       'totalSellQuantity': 6525,
#                       'totalTradedVolume': 1,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 13950,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.6499999999999999,
#                       'changeinOpenInterest': 1422,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE23050.00',
#                       'impliedVolatility': 36.07,
#                       'lastPrice': 0.05,
#                       'openInterest': 2257,
#                       'pChange': -92.85714285714285,
#                       'pchangeinOpenInterest': 170.2994011976048,
#                       'strikePrice': 23050,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 121650,
#                       'totalTradedVolume': 39377,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 23050},
#             { 'CE': { 'askPrice': 1411.5,
#                       'askQty': 150,
#                       'bidQty': 225,
#                       'bidprice': 1386.75,
#                       'change': -286.04999999999995,
#                       'changeinOpenInterest': -2,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23100.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 1403.55,
#                       'openInterest': 28,
#                       'pChange': -16.930042613636363,
#                       'pchangeinOpenInterest': -6.666666666666667,
#                       'strikePrice': 23100,
#                       'totalBuyQuantity': 6375,
#                       'totalSellQuantity': 6525,
#                       'totalTradedVolume': 9,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 2625,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.7,
#                       'changeinOpenInterest': 4746,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE23100.00',
#                       'impliedVolatility': 34.92,
#                       'lastPrice': 0.05,
#                       'openInterest': 8032,
#                       'pChange': -93.33333333333333,
#                       'pchangeinOpenInterest': 144.43091905051736,
#                       'strikePrice': 23100,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 93225,
#                       'totalTradedVolume': 65163,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 23100},
#             { 'CE': { 'askPrice': 1363.6,
#                       'askQty': 225,
#                       'bidQty': 150,
#                       'bidprice': 1262.4,
#                       'change': -125.15000000000009,
#                       'changeinOpenInterest': -2,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23150.00',
#                       'impliedVolatility': 85.47,
#                       'lastPrice': 1445,
#                       'openInterest': 10,
#                       'pChange': -7.970576059612144,
#                       'pchangeinOpenInterest': -16.666666666666668,
#                       'strikePrice': 23150,
#                       'totalBuyQuantity': 6300,
#                       'totalSellQuantity': 6525,
#                       'totalTradedVolume': 2,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 750,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.7,
#                       'changeinOpenInterest': 1415,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE23150.00',
#                       'impliedVolatility': 33.76,
#                       'lastPrice': 0.05,
#                       'openInterest': 2248,
#                       'pChange': -93.33333333333333,
#                       'pchangeinOpenInterest': 169.86794717887156,
#                       'strikePrice': 23150,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 96450,
#                       'totalTradedVolume': 41874,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 23150},
#             { 'CE': { 'askPrice': 1311.35,
#                       'askQty': 75,
#                       'bidQty': 75,
#                       'bidprice': 1292.2,
#                       'change': -233.75,
#                       'changeinOpenInterest': -8,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23200.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 1296.25,
#                       'openInterest': 28,
#                       'pChange': -15.277777777777779,
#                       'pchangeinOpenInterest': -22.22222222222222,
#                       'strikePrice': 23200,
#                       'totalBuyQuantity': 6300,
#                       'totalSellQuantity': 6225,
#                       'totalTradedVolume': 21,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 1125,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.6499999999999999,
#                       'changeinOpenInterest': -2123,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE23200.00',
#                       'impliedVolatility': 32.61,
#                       'lastPrice': 0.05,
#                       'openInterest': 9502,
#                       'pChange': -92.85714285714285,
#                       'pchangeinOpenInterest': -18.26236559139785,
#                       'strikePrice': 23200,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 116175,
#                       'totalTradedVolume': 104304,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 23200},
#             { 'CE': { 'askPrice': 1264.55,
#                       'askQty': 225,
#                       'bidQty': 225,
#                       'bidprice': 1242.5,
#                       'change': 0,
#                       'changeinOpenInterest': 0,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23250.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 1740.05,
#                       'openInterest': 6,
#                       'pChange': 0,
#                       'pchangeinOpenInterest': 0,
#                       'strikePrice': 23250,
#                       'totalBuyQuantity': 5025,
#                       'totalSellQuantity': 6375,
#                       'totalTradedVolume': 0,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 10050,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.85,
#                       'changeinOpenInterest': 321,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE23250.00',
#                       'impliedVolatility': 31.45,
#                       'lastPrice': 0.05,
#                       'openInterest': 2514,
#                       'pChange': -94.44444444444444,
#                       'pchangeinOpenInterest': 14.6374829001368,
#                       'strikePrice': 23250,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 108375,
#                       'totalTradedVolume': 58363,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 23250},
#             { 'CE': { 'askPrice': 1211.65,
#                       'askQty': 225,
#                       'bidQty': 300,
#                       'bidprice': 1120,
#                       'change': -250.95000000000005,
#                       'changeinOpenInterest': 13,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23300.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 1185.55,
#                       'openInterest': 61,
#                       'pChange': -17.469544030630008,
#                       'pchangeinOpenInterest': 27.083333333333332,
#                       'strikePrice': 23300,
#                       'totalBuyQuantity': 6750,
#                       'totalSellQuantity': 6675,
#                       'totalTradedVolume': 65,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 20250,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.7999999999999999,
#                       'changeinOpenInterest': 4131,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE23300.00',
#                       'impliedVolatility': 30.29,
#                       'lastPrice': 0.05,
#                       'openInterest': 10131,
#                       'pChange': -94.11764705882352,
#                       'pchangeinOpenInterest': 68.85,
#                       'strikePrice': 23300,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 165150,
#                       'totalTradedVolume': 129910,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 23300},
#             { 'CE': { 'askPrice': 1163.85,
#                       'askQty': 225,
#                       'bidQty': 300,
#                       'bidprice': 1016.3,
#                       'change': 0,
#                       'changeinOpenInterest': 0,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23350.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 1411.7,
#                       'openInterest': 32,
#                       'pChange': 0,
#                       'pchangeinOpenInterest': 0,
#                       'strikePrice': 23350,
#                       'totalBuyQuantity': 7050,
#                       'totalSellQuantity': 6675,
#                       'totalTradedVolume': 0,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 6525,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.75,
#                       'changeinOpenInterest': 849,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE23350.00',
#                       'impliedVolatility': 29.14,
#                       'lastPrice': 0.05,
#                       'openInterest': 2513,
#                       'pChange': -93.75,
#                       'pchangeinOpenInterest': 51.02163461538461,
#                       'strikePrice': 23350,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 99825,
#                       'totalTradedVolume': 57514,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 23350},
#             { 'CE': { 'askPrice': 1111.6,
#                       'askQty': 225,
#                       'bidQty': 225,
#                       'bidprice': 1093.6,
#                       'change': -278.64999999999986,
#                       'changeinOpenInterest': 23,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23400.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 1085.4,
#                       'openInterest': 83,
#                       'pChange': -20.428136798504447,
#                       'pchangeinOpenInterest': 38.333333333333336,
#                       'strikePrice': 23400,
#                       'totalBuyQuantity': 6525,
#                       'totalSellQuantity': 6675,
#                       'totalTradedVolume': 53,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 3450,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.75,
#                       'changeinOpenInterest': 12412,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE23400.00',
#                       'impliedVolatility': 27.98,
#                       'lastPrice': 0.05,
#                       'openInterest': 17479,
#                       'pChange': -93.75,
#                       'pchangeinOpenInterest': 244.9575685810144,
#                       'strikePrice': 23400,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 102225,
#                       'totalTradedVolume': 230292,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 23400},
#             { 'CE': { 'askPrice': 1058.05,
#                       'askQty': 75,
#                       'bidQty': 75,
#                       'bidprice': 1042.55,
#                       'change': -288.85000000000014,
#                       'changeinOpenInterest': 34,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23450.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 1046.3,
#                       'openInterest': 72,
#                       'pChange': -21.634273302625182,
#                       'pchangeinOpenInterest': 89.47368421052632,
#                       'strikePrice': 23450,
#                       'totalBuyQuantity': 6600,
#                       'totalSellQuantity': 6525,
#                       'totalTradedVolume': 81,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 150,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.8999999999999999,
#                       'changeinOpenInterest': 822,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE23450.00',
#                       'impliedVolatility': 26.82,
#                       'lastPrice': 0.05,
#                       'openInterest': 3113,
#                       'pChange': -94.73684210526315,
#                       'pchangeinOpenInterest': 35.879528590135315,
#                       'strikePrice': 23450,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 115650,
#                       'totalTradedVolume': 95178,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 23450},
#             { 'CE': { 'askPrice': 1003.1,
#                       'askQty': 75,
#                       'bidQty': 75,
#                       'bidprice': 1000.7,
#                       'change': -232.85000000000002,
#                       'changeinOpenInterest': -724,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23500.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 1003.1,
#                       'openInterest': 2370,
#                       'pChange': -18.839758889922734,
#                       'pchangeinOpenInterest': -23.400129282482222,
#                       'strikePrice': 23500,
#                       'totalBuyQuantity': 12000,
#                       'totalSellQuantity': 8100,
#                       'totalTradedVolume': 2441,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 96600,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.8999999999999999,
#                       'changeinOpenInterest': 39456,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE23500.00',
#                       'impliedVolatility': 25.67,
#                       'lastPrice': 0.05,
#                       'openInterest': 73551,
#                       'pChange': -94.73684210526315,
#                       'pchangeinOpenInterest': 115.72371315442147,
#                       'strikePrice': 23500,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 200475,
#                       'totalTradedVolume': 720389,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 23500},
#             { 'CE': { 'askPrice': 956.55,
#                       'askQty': 300,
#                       'bidQty': 75,
#                       'bidprice': 943,
#                       'change': -235.04999999999995,
#                       'changeinOpenInterest': 18,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23550.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 954.95,
#                       'openInterest': 37,
#                       'pChange': -19.75210084033613,
#                       'pchangeinOpenInterest': 94.73684210526316,
#                       'strikePrice': 23550,
#                       'totalBuyQuantity': 6150,
#                       'totalSellQuantity': 6525,
#                       'totalTradedVolume': 89,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 6000,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.8999999999999999,
#                       'changeinOpenInterest': 627,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE23550.00',
#                       'impliedVolatility': 24.51,
#                       'lastPrice': 0.05,
#                       'openInterest': 3328,
#                       'pChange': -94.73684210526315,
#                       'pchangeinOpenInterest': 23.213624583487597,
#                       'strikePrice': 23550,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 215100,
#                       'totalTradedVolume': 130350,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 23550},
#             { 'CE': { 'askPrice': 910.25,
#                       'askQty': 75,
#                       'bidQty': 225,
#                       'bidprice': 893.6,
#                       'change': -227.85000000000002,
#                       'changeinOpenInterest': -13,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23600.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 894.35,
#                       'openInterest': 75,
#                       'pChange': -20.303867403314918,
#                       'pchangeinOpenInterest': -14.772727272727273,
#                       'strikePrice': 23600,
#                       'totalBuyQuantity': 7275,
#                       'totalSellQuantity': 7425,
#                       'totalTradedVolume': 192,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 198600,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.95,
#                       'changeinOpenInterest': 11964,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE23600.00',
#                       'impliedVolatility': 23.35,
#                       'lastPrice': 0.05,
#                       'openInterest': 21080,
#                       'pChange': -95,
#                       'pchangeinOpenInterest': 131.24177270732778,
#                       'strikePrice': 23600,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 309675,
#                       'totalTradedVolume': 314380,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 23600},
#             { 'CE': { 'askPrice': 853.95,
#                       'askQty': 300,
#                       'bidQty': 300,
#                       'bidprice': 841.25,
#                       'change': -237.60000000000002,
#                       'changeinOpenInterest': 57,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23650.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 852.4,
#                       'openInterest': 101,
#                       'pChange': -21.79816513761468,
#                       'pchangeinOpenInterest': 129.54545454545453,
#                       'strikePrice': 23650,
#                       'totalBuyQuantity': 11775,
#                       'totalSellQuantity': 6825,
#                       'totalTradedVolume': 134,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 24525,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.8999999999999999,
#                       'changeinOpenInterest': 4096,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE23650.00',
#                       'impliedVolatility': 22.18,
#                       'lastPrice': 0.05,
#                       'openInterest': 9116,
#                       'pChange': -94.73684210526315,
#                       'pchangeinOpenInterest': 81.59362549800797,
#                       'strikePrice': 23650,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 71025,
#                       'totalTradedVolume': 180703,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 23650},
#             { 'CE': { 'askPrice': 803.7,
#                       'askQty': 75,
#                       'bidQty': 225,
#                       'bidprice': 796.05,
#                       'change': -227.9000000000001,
#                       'changeinOpenInterest': -4,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23700.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 802.3,
#                       'openInterest': 94,
#                       'pChange': -22.121918074160366,
#                       'pchangeinOpenInterest': -4.081632653061225,
#                       'strikePrice': 23700,
#                       'totalBuyQuantity': 5400,
#                       'totalSellQuantity': 6975,
#                       'totalTradedVolume': 176,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 11400,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -1,
#                       'changeinOpenInterest': 4330,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE23700.00',
#                       'impliedVolatility': 21.02,
#                       'lastPrice': 0.05,
#                       'openInterest': 25664,
#                       'pChange': -95.23809523809523,
#                       'pchangeinOpenInterest': 20.296240742476797,
#                       'strikePrice': 23700,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 70575,
#                       'totalTradedVolume': 454205,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 23700},
#             { 'CE': { 'askPrice': 754,
#                       'askQty': 75,
#                       'bidQty': 225,
#                       'bidprice': 746.15,
#                       'change': -237.29999999999995,
#                       'changeinOpenInterest': 68,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23750.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 752.5,
#                       'openInterest': 108,
#                       'pChange': -23.97454031117397,
#                       'pchangeinOpenInterest': 170,
#                       'strikePrice': 23750,
#                       'totalBuyQuantity': 8925,
#                       'totalSellQuantity': 6675,
#                       'totalTradedVolume': 165,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 18300,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -1.15,
#                       'changeinOpenInterest': 4815,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE23750.00',
#                       'impliedVolatility': 19.85,
#                       'lastPrice': 0.05,
#                       'openInterest': 10941,
#                       'pChange': -95.83333333333333,
#                       'pchangeinOpenInterest': 78.5994123408423,
#                       'strikePrice': 23750,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 75225,
#                       'totalTradedVolume': 368491,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 23750},
#             { 'CE': { 'askPrice': 702.95,
#                       'askQty': 75,
#                       'bidQty': 300,
#                       'bidprice': 694.25,
#                       'change': -239.05000000000007,
#                       'changeinOpenInterest': 7,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23800.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 703.65,
#                       'openInterest': 168,
#                       'pChange': -25.3580142144903,
#                       'pchangeinOpenInterest': 4.3478260869565215,
#                       'strikePrice': 23800,
#                       'totalBuyQuantity': 10650,
#                       'totalSellQuantity': 7275,
#                       'totalTradedVolume': 287,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 0.05,
#                       'askQty': 7200,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -1.3,
#                       'changeinOpenInterest': 5916,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE23800.00',
#                       'impliedVolatility': 18.68,
#                       'lastPrice': 0.05,
#                       'openInterest': 58690,
#                       'pChange': -96.29629629629629,
#                       'pchangeinOpenInterest': 11.210065562587637,
#                       'strikePrice': 23800,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 184500,
#                       'totalTradedVolume': 831139,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 23800},
#             { 'CE': { 'askPrice': 653.35,
#                       'askQty': 75,
#                       'bidQty': 300,
#                       'bidprice': 644.2,
#                       'change': -229.89999999999998,
#                       'changeinOpenInterest': 99,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE23850.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 653.7,
#                       'openInterest': 144,
#                       'pChange': -26.01856043458578,
#                       'pchangeinOpenInterest': 220,
#                       'strikePrice': 23850,
# ...
#                       'askQty': 375,
#                       'bidQty': 75,
#                       'bidprice': 2497.05,
#                       'change': 232.94999999999982,
#                       'changeinOpenInterest': -392,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE27000.00',
#                       'impliedVolatility': 123.64,
#                       'lastPrice': 2503.5,
#                       'openInterest': 4760,
#                       'pChange': 10.259628724317887,
#                       'pchangeinOpenInterest': -7.608695652173913,
#                       'strikePrice': 27000,
#                       'totalBuyQuantity': 9300,
#                       'totalSellQuantity': 8700,
#                       'totalTradedVolume': 2777,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 27000},
#             { 'CE': { 'askPrice': 0.05,
#                       'askQty': 225,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -1.05,
#                       'changeinOpenInterest': 1597,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE27050.00',
#                       'impliedVolatility': 53.63,
#                       'lastPrice': 0.05,
#                       'openInterest': 2347,
#                       'pChange': -95.45454545454545,
#                       'pchangeinOpenInterest': 212.93333333333334,
#                       'strikePrice': 27050,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 115125,
#                       'totalTradedVolume': 28749,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 2572.65,
#                       'askQty': 225,
#                       'bidQty': 225,
#                       'bidprice': 2529.35,
#                       'change': 1.900000000000091,
#                       'changeinOpenInterest': 0,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE27050.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 2064.9,
#                       'openInterest': 8,
#                       'pChange': 0.0920988851187635,
#                       'pchangeinOpenInterest': 0,
#                       'strikePrice': 27050,
#                       'totalBuyQuantity': 6825,
#                       'totalSellQuantity': 6825,
#                       'totalTradedVolume': 0,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 27050},
#             { 'CE': { 'askPrice': 0.05,
#                       'askQty': 150,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.85,
#                       'changeinOpenInterest': 719,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE27100.00',
#                       'impliedVolatility': 57.34,
#                       'lastPrice': 0.1,
#                       'openInterest': 1355,
#                       'pChange': -89.47368421052632,
#                       'pchangeinOpenInterest': 113.0503144654088,
#                       'strikePrice': 27100,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 124800,
#                       'totalTradedVolume': 25464,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 2617.3,
#                       'askQty': 225,
#                       'bidQty': 225,
#                       'bidprice': 2579.2,
#                       'change': 416.1500000000001,
#                       'changeinOpenInterest': -1,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE27100.00',
#                       'impliedVolatility': 101.14,
#                       'lastPrice': 2567.75,
#                       'openInterest': 6,
#                       'pChange': 19.341420338352858,
#                       'pchangeinOpenInterest': -14.285714285714286,
#                       'strikePrice': 27100,
#                       'totalBuyQuantity': 6525,
#                       'totalSellQuantity': 6675,
#                       'totalTradedVolume': 2,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 27100},
#             { 'CE': { 'askPrice': 0.1,
#                       'askQty': 2850,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.8999999999999999,
#                       'changeinOpenInterest': 213,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE27150.00',
#                       'impliedVolatility': 55.52,
#                       'lastPrice': 0.05,
#                       'openInterest': 767,
#                       'pChange': -94.73684210526315,
#                       'pchangeinOpenInterest': 38.44765342960289,
#                       'strikePrice': 27150,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 126375,
#                       'totalTradedVolume': 19478,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 2673.6,
#                       'askQty': 225,
#                       'bidQty': 225,
#                       'bidprice': 2629.55,
#                       'change': 507.39999999999964,
#                       'changeinOpenInterest': 0,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE27150.00',
#                       'impliedVolatility': 127.49,
#                       'lastPrice': 2650.7,
#                       'openInterest': 9,
#                       'pChange': 23.67377408668873,
#                       'pchangeinOpenInterest': 0,
#                       'strikePrice': 27150,
#                       'totalBuyQuantity': 6675,
#                       'totalSellQuantity': 6675,
#                       'totalTradedVolume': 13,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 27150},
#             { 'CE': { 'askPrice': 0.05,
#                       'askQty': 8550,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.8999999999999999,
#                       'changeinOpenInterest': 60,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE27200.00',
#                       'impliedVolatility': 56.47,
#                       'lastPrice': 0.05,
#                       'openInterest': 1339,
#                       'pChange': -94.73684210526315,
#                       'pchangeinOpenInterest': 4.691164972634871,
#                       'strikePrice': 27200,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 134175,
#                       'totalTradedVolume': 23976,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 2726.05,
#                       'askQty': 225,
#                       'bidQty': 225,
#                       'bidprice': 2679.2,
#                       'change': 307.3499999999999,
#                       'changeinOpenInterest': 0,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE27200.00',
#                       'impliedVolatility': 131.17,
#                       'lastPrice': 2704,
#                       'openInterest': 8,
#                       'pChange': 12.824150376567287,
#                       'pchangeinOpenInterest': 0,
#                       'strikePrice': 27200,
#                       'totalBuyQuantity': 6675,
#                       'totalSellQuantity': 6675,
#                       'totalTradedVolume': 7,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 27200},
#             { 'CE': { 'askPrice': 0.05,
#                       'askQty': 6375,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.7999999999999999,
#                       'changeinOpenInterest': 133,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE27250.00',
#                       'impliedVolatility': 57.4,
#                       'lastPrice': 0.05,
#                       'openInterest': 931,
#                       'pChange': -94.11764705882352,
#                       'pchangeinOpenInterest': 16.666666666666668,
#                       'strikePrice': 27250,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 115050,
#                       'totalTradedVolume': 18223,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 2772.45,
#                       'askQty': 225,
#                       'bidQty': 225,
#                       'bidprice': 2729.2,
#                       'change': 0,
#                       'changeinOpenInterest': 0,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE27250.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 2242.9,
#                       'openInterest': 9,
#                       'pChange': 0,
#                       'pchangeinOpenInterest': 0,
#                       'strikePrice': 27250,
#                       'totalBuyQuantity': 6525,
#                       'totalSellQuantity': 6825,
#                       'totalTradedVolume': 0,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 27250},
#             { 'CE': { 'askPrice': 0.05,
#                       'askQty': 14175,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.75,
#                       'changeinOpenInterest': 443,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE27300.00',
#                       'impliedVolatility': 58.34,
#                       'lastPrice': 0.05,
#                       'openInterest': 2101,
#                       'pChange': -93.75,
#                       'pchangeinOpenInterest': 26.7189384800965,
#                       'strikePrice': 27300,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 117150,
#                       'totalTradedVolume': 32196,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 2822.6,
#                       'askQty': 225,
#                       'bidQty': 225,
#                       'bidprice': 2778.65,
#                       'change': 0,
#                       'changeinOpenInterest': 0,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE27300.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 2526,
#                       'openInterest': 12,
#                       'pChange': 0,
#                       'pchangeinOpenInterest': 0,
#                       'strikePrice': 27300,
#                       'totalBuyQuantity': 6825,
#                       'totalSellQuantity': 6525,
#                       'totalTradedVolume': 0,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 27300},
#             { 'CE': { 'askPrice': 0.05,
#                       'askQty': 2025,
#                       'bidQty': 0,
#                       'bidprice': 0,
#                       'change': -0.7,
#                       'changeinOpenInterest': 43,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE27350.00',
#                       'impliedVolatility': 59.27,
#                       'lastPrice': 0.05,
#                       'openInterest': 2478,
#                       'pChange': -93.33333333333333,
#                       'pchangeinOpenInterest': 1.7659137577002053,
#                       'strikePrice': 27350,
#                       'totalBuyQuantity': 0,
#                       'totalSellQuantity': 115125,
#                       'totalTradedVolume': 34424,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 2873.3,
#                       'askQty': 225,
#                       'bidQty': 225,
#                       'bidprice': 2828.85,
#                       'change': 0,
#                       'changeinOpenInterest': 0,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE27350.00',
#                       'impliedVolatility': 0,
#                       'lastPrice': 2342.45,
#                       'openInterest': 9,
#                       'pChange': 0,
#                       'pchangeinOpenInterest': 0,
#                       'strikePrice': 27350,
#                       'totalBuyQuantity': 6525,
#                       'totalSellQuantity': 6375,
#                       'totalTradedVolume': 0,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 27350},
#             { 'CE': { 'askPrice': 0.1,
#                       'askQty': 11925,
#                       'bidQty': 27975,
#                       'bidprice': 0.05,
#                       'change': -0.75,
#                       'changeinOpenInterest': 2730,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025CE27400.00',
#                       'impliedVolatility': 60.2,
#                       'lastPrice': 0.05,
#                       'openInterest': 32320,
#                       'pChange': -93.75,
#                       'pchangeinOpenInterest': 9.226089895234876,
#                       'strikePrice': 27400,
#                       'totalBuyQuantity': 27975,
#                       'totalSellQuantity': 132825,
#                       'totalTradedVolume': 276256,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'PE': { 'askPrice': 2918.65,
#                       'askQty': 225,
#                       'bidQty': 225,
#                       'bidprice': 2882.1,
#                       'change': 227.14999999999964,
#                       'changeinOpenInterest': -53,
#                       'expiryDate': '28-Aug-2025',
#                       'identifier': 'OPTIDXNIFTY28-08-2025PE27400.00',
#                       'impliedVolatility': 138.7,
#                       'lastPrice': 2904.7,
#                       'openInterest': 105,
#                       'pChange': 8.483501708651552,
#                       'pchangeinOpenInterest': -33.54430379746835,
#                       'strikePrice': 27400,
#                       'totalBuyQuantity': 7050,
#                       'totalSellQuantity': 6600,
#                       'totalTradedVolume': 125,
#                       'underlying': 'NIFTY',
#                       'underlyingValue': 24500.9},
#               'expiryDate': '28-Aug-2025',
#               'strikePrice': 27400}]}
